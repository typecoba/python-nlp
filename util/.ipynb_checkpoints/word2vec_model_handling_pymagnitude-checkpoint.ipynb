# %% [markdown]
# ### pymagnitude library
# - pip3 install pymagnitude 설치
# - 연산 패키지.. 정보가 왜이리 없지?

# %%
from pymagnitude import Magnitude
mpath = '../data/ta_hashtag/vectors.txt'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-8f346787cfad> in <module>()
# ----> 1 from pymagnitude import Magnitude
#       2 mpath = '../data/ta_hashtag/vectors.txt'
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\pymagnitude\__init__.py in <module>()
#      78 sys.path.append(os.path.dirname(__file__) + '/third_party/')
#      79 sys.path.append(os.path.dirname(__file__) + '/third_party_mock/')
# ---> 80 from pymagnitude.third_party.allennlp.commands.elmo import ElmoEmbedder
#      81
#      82 # Import SQLite
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\pymagnitude\third_party\allennlp\commands\__init__.py in <module>()
#       6
#       7
# ----> 8 from allennlp.commands.configure import Configure
#       9 from allennlp.commands.elmo import Elmo
#      10 from allennlp.commands.evaluate import Evaluate
#
# ...

# %% [markdown]
# ### magnitude library
