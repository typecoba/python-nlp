# %%
from soynlp.utils import DoublespaceLineCorpus
from pprint import pprint
fpath = './data/hashtag/md_cpm_hashtag.txt'

# %%
corpus = DoublespaceLineCorpus(fpath, iter_sent=True)

# %%
pprint(list(corpus)[:50])
# Out:
# ['듀오안,신바이오틱스,신바이오틱스뉴리더,박서준요거트,서울우유,유산균,요거트',
#  '풀무원,생면식감,꼬불꼬불물냉면,꼬불냉면,물냉,비냉,물냉면,비빔냉면',
#  '풀무원,생면식감,한화이글스,11번가,마라탕,마라탕면,생면식감마라탕면,한화이글스마라탕면,포기하지마라탕면',
#  '내추럴더마프로젝트,시카바이오플라센타크림,자연을담은더마,착한성분,피부진정,피부트러블개선',
#  'AMUSE,어뮤즈,뉴트로매트,나르시즘,1998,마드모아젤',
#  '유니클로,썸머파이널세일,유니클로세일,UNIQLO,유니클로광고,Summersale,유니클로라이프웨어',
#  '유니클로,썸머파이널세일,유니클로세일,UNIQLO,유니클로광고,Summersale,유니클로라이프웨어',
#  '로제타스톤,영어독서,영어말하기,영어스피킹,홈스쿨링,영어,영어스터디,초등영어,어린이영어,유아영어',
#  '코로니타,한입보틀,미니코로나,코로니타엔라임,코로나엔라임,혼술,혼맥,맥주스타그램,10분휴가,일상속여유,맥주테라피,협찬',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈프리미엄,협찬',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈다이닝,협찬',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈다이닝,협찬',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈프리미엄,협찬',
#  '오일러스,건면,GS25,심야포차국수,편의점음식추천',
#  'AD,협찬광고,VDL,브이디엘,퍼펙트핏파운데이션,마그넷파데,프로핏파데,스킨핏파데,파운데이션,씬님,협찬리뷰,sponsored',
#  'AD,협찬광고,VDL,브이디엘,퍼펙트핏파운데이션,마그넷파데,프로핏파데,스킨핏파데,파운데이션,씬님,협찬리뷰,sponsored',
#  'VDL팝서퍼컬렉션,VDL썸머컬렉션,협찬광고,AD,팝서퍼컬렉션,트리플샷,트리플컬러립,협찬리뷰,SPONSERED',
#  '에어리매트,글로우매트,KATE,THEBASEZERO,더베이스제로,시크린스킨메이커,파우더리스킨메이커,올리브영추천,AD',
#  '켈로그,첵스,첵스초코,첵스초코마시멜로,첵스초코 AR에디션,첵스초코증강현실체험팩,시리얼,AR,증강현실,아이놀이',
#  '맥도날드,맥도날드아이스크림,베리스트로베리,맥도날드칠러,파인애플칠러,그냥칠러',
#  '맥도날드,맥도날드아이스크림,베리스트로베리,맥도날드칠러,파인애플칠러,그냥칠러',
#  '맥도날드,맥도날드아이스크림,베리스트로베리,맥도날드칠러,파인애플칠러,그냥칠러',
#  '맥도날드,맥도날드아이스크림,베리스트로베리,맥도날드칠러,파인애플칠러,그냥칠러',
#  '코로니타,한입보틀,미니코로나,코로니타엔라임,코로나엔라임,혼술,혼맥,맥주스타그램,10분휴가,일상속여유,맥주테라피,협찬',
#  '디픈,소유마스크팩,마스크팩추천,1일1팩효과,피부진정팩,수분마스크팩,극세사시트,미백마스크팩,diipn,셀피,체크앤바이,checknbuy',
#  '홈키파홈매트,홈키파,홈키파마이키파,홈키파캠핑에어졸,캠핑에어졸,모기기피제,모기퇴치제,캠핑용품',
#  '서울우유,요하임,아이간식,어린이간식 ,가족간식 ,요거트 ,요거트추천 ,맛있는요거트 ,요거트맛집',
#  '니베아,데오드란트,언더암케어,드라이콤포트',
#  '니베아,데오드란트,언더암케어,엑스트라화이트,여름필수템,화이트닝',
#  '니베아,데오드란트,언더암케어,퍼퓸데오드란트,패뷸러스플라워,스플래시라임,매직펄,퍼퓸데오,향수추천',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈프리미엄,협찬',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈프리미엄,협찬',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈다이닝,협찬',
#  '산토리맥주,산토리프리미엄몰트,산토리카오루에일,산토리뉴크리미서버,노워시,일본프리미엄맥주,크리미맥주,맥주스타그램,홈다이닝,협찬',
#  '링거워터,링티,수분충전,일상,운동,야근,필수템,인싸템',
#  '애플폭스,applefox,애플사이다,여우도반한달콤한청량감',
#  '코로니타,한입보틀,미니코로나,코로니타엔라임,코로나엔라임,혼술,혼맥,맥주스타그램,10분휴가,일상속여유,맥주테라피,AD',
#  '2XU,투엑스유,너를두배로',
#  '애플폭스,applefox,애플사이다,여우도반한달콤한청량감',
#  '바루랩,블랙클레이마스크팩,피지각질제거,1일1팩,머드팩,홈케어,모공케어,모공팩추천,마스크팩추천,노폐물제거',
#  '바루랩,로션,여드름,흉터치료,아토피,홍조,재생크림,살브크림,연고크림,피부관리,건성,복합성,보습,화장품추천',
#  '세상을바꾸는치킨,노랑통닭',
#  '코로니타,한입보틀,미니코로나,코로니타엔라임,코로나엔라임,혼술,혼맥,맥주스타그램,10분휴가,일상속여유,맥주테라피,협찬',
#  '텍스트가이드확인하여 기입',
#  '텍스트가이드확인하여 기입',
#  '텍스트가이드확인하여 기입',
#  '스텔라아르투아,Becomeanicon,꿈은단절되지않는다,스텔라한잔,아이콘투아이콘,스텔라기부캠페인,협찬',
#  '스텔라아르투아,Becomeanicon,꿈은단절되지않는다,스텔라한잔,아이콘투아이콘,스텔라기부캠페인,협찬',
#  '스텔라아르투아,Becomeanicon,꿈은단절되지않는다,스텔라한잔,아이콘투아이콘,스텔라기부캠페인,협찬',
#  '스텔라아르투아,Becomeanicon,꿈은단절되지않는다,스텔라한잔,아이콘투아이콘,스텔라기부캠페인,협찬']

# %%
tags = []
for i,sent in enumerate(corpus) :     
    splited_sent = sent.split(',')
    for word in splited_sent : 
        if word not in tags : 
            tags.append(word)

# %%
print(len(tags))
pprint(tags)
# Out:
# 4396
# ['듀오안',
#  '신바이오틱스',
#  '신바이오틱스뉴리더',
#  '박서준요거트',
#  '서울우유',
#  '유산균',
#  '요거트',
#  '풀무원',
#  '생면식감',
#  '꼬불꼬불물냉면',
#  '꼬불냉면',
#  '물냉',
#  '비냉',
#  '물냉면',
#  '비빔냉면',
#  '한화이글스',
#  '11번가',
#  '마라탕',
#  '마라탕면',
#  '생면식감마라탕면',
#  '한화이글스마라탕면',
#  '포기하지마라탕면',
#  '내추럴더마프로젝트',
#  '시카바이오플라센타크림',
#  '자연을담은더마',
#  '착한성분',
#  '피부진정',
#  '피부트러블개선',
#  'AMUSE',
#  '어뮤즈',
#  '뉴트로매트',
#  '나르시즘',
#  '1998',
#  '마드모아젤',
#  '유니클로',
#  '썸머파이널세일',
#  '유니클로세일',
#  'UNIQLO',
#  '유니클로광고',
#  'Summersale',
#  '유니클로라이프웨어',
#  '로제타스톤',
#  '영어독서',
#  '영어말하기',
#  '영어스피킹',
#  '홈스쿨링',
#  '영어',
#  '영어스터디',
#  '초등영어',
#  '어린이영어',
#  '유아영어',
#  '코로니타',
#  '한입보틀',
#  '미니코로나',
#  '코로니타엔라임',
#  '코로나엔라임',
#  '혼술',
#  '혼맥',
#  '맥주스타그램',
#  '10분휴가',
#  '일상속여유',
#  '맥주테라피',
#  '협찬',
#  '산토리맥주',
#  '산토리프리미엄몰트',
#  '산토리카오루에일',
#  '산토리뉴크리미서버',
#  '노워시',
#  '일본프리미엄맥주',
#  '크리미맥주',
#  '홈프리미엄',
#  '홈다이닝',
#  '오일러스',
#  '건면',
#  'GS25',
#  '심야포차국수',
#  '편의점음식추천',
#  'AD',
#  '협찬광고',
#  'VDL',
#  '브이디엘',
#  '퍼펙트핏파운데이션',
#  '마그넷파데',
#  '프로핏파데',
#  '스킨핏파데',
#  '파운데이션',
#  '씬님',
#  '협찬리뷰',
#  'sponsored',
#  'VDL팝서퍼컬렉션',
#  'VDL썸머컬렉션',
#  '팝서퍼컬렉션',
#  '트리플샷',
#  '트리플컬러립',
#  'SPONSERED',
#  '에어리매트',
#  '글로우매트',
#  'KATE',
#  'THEBASEZERO',
#  '더베이스제로',
#  '시크린스킨메이커',
#  '파우더리스킨메이커',
#  '올리브영추천',
#  '켈로그',
#  '첵스',
#  '첵스초코',
#  '첵스초코마시멜로',
#  '첵스초코 AR에디션',
#  '첵스초코증강현실체험팩',
#  '시리얼',
#  'AR',
#  '증강현실',
#  '아이놀이',
#  '맥도날드',
#  '맥도날드아이스크림',
#  '베리스트로베리',
#  '맥도날드칠러',
#  '파인애플칠러',
#  '그냥칠러',
#  '디픈',
#  '소유마스크팩',
#  '마스크팩추천',
#  '1일1팩효과',
#  '피부진정팩',
#  '수분마스크팩',
#  '극세사시트',
#  '미백마스크팩',
#  'diipn',
#  '셀피',
#  '체크앤바이',
#  'checknbuy',
#  '홈키파홈매트',
#  '홈키파',
#  '홈키파마이키파',
#  '홈키파캠핑에어졸',
#  '캠핑에어졸',
#  '모기기피제',
#  '모기퇴치제',
#  '캠핑용품',
#  '요하임',
#  '아이간식',
#  '어린이간식 ',
#  '가족간식 ',
#  '요거트 ',
#  '요거트추천 ',
#  '맛있는요거트 ',
#  '요거트맛집',
#  '니베아',
#  '데오드란트',
#  '언더암케어',
#  '드라이콤포트',
#  '엑스트라화이트',
#  '여름필수템',
#  '화이트닝',
#  '퍼퓸데오드란트',
#  '패뷸러스플라워',
#  '스플래시라임',
#  '매직펄',
#  '퍼퓸데오',
#  '향수추천',
#  '링거워터',
#  '링티',
#  '수분충전',
#  '일상',
#  '운동',
#  '야근',
#  '필수템',
#  '인싸템',
#  '애플폭스',
#  'applefox',
#  '애플사이다',
#  '여우도반한달콤한청량감',
#  '2XU',
#  '투엑스유',
#  '너를두배로',
#  '바루랩',
#  '블랙클레이마스크팩',
#  '피지각질제거',
#  '1일1팩',
#  '머드팩',
#  '홈케어',
#  '모공케어',
#  '모공팩추천',
#  '노폐물제거',
#  '로션',
#  '여드름',
#  '흉터치료',
#  '아토피',
#  '홍조',
#  '재생크림',
#  '살브크림',
#  '연고크림',
#  '피부관리',
#  '건성',
#  '복합성',
#  '보습',
#  '화장품추천',
#  '세상을바꾸는치킨',
#  '노랑통닭',
#  '텍스트가이드확인하여 기입',
#  '스텔라아르투아',
#  'Becomeanicon',
#  '꿈은단절되지않는다',
#  '스텔라한잔',
#  '아이콘투아이콘',
#  '스텔라기부캠페인',
#  '트윈워시댄스챌린지',
#  'LG트롬트윈워시',
#  '트롬세척기',
#  '트윈워시',
#  'LG세탁기',
#  '세탁기',
#  '댄스',
#  '이벤트',
#  '춤스타그램',
#  '댄스스타그램',
#  '#sponsored_by_엘지',
#  '아레나',
#  '아레나코리아',
#  '아레나수영복',
#  '벨라몬스터',
#  '홈쇼핑',
#  '당근패드',
#  '사전구매',
#  '일정',
#  '초특가',
#  '할인',
#  '울트라모이스처핸드크림',
#  '핸드크림추천',
#  '향좋은핸드크림',
#  '건조한손',
#  '파우치잇템',
#  '슈퍼콘댄스',
#  '손흥민춤',
#  '슈퍼콘댄스챌린지',
#  '슈퍼콘',
#  'DGSMEG',
#  '스메그',
#  'SMEG',
#  '다이치',
#  '다이치유모차',
#  '절충형유모차',
#  '다이치루이',
#  '다이치유모차앨리',
#  '다이치루이유모차',
#  '다이치앨리',
#  '유모자추천',
#  '다이치카시트',
#  '다이치아기띠',
#  '바르다김선생',
#  '바르다김선생신메뉴',
#  '김선생신메뉴',
#  '치즈가락떡볶이',
#  '순메밀회냉면',
#  '무나물꼬막비빔밥',
#  '유료광고',
#  '레디고신세계',
#  'readygoshinsegae',
#  '신세계면세점',
#  '여행스타그램',
#  '여행',
#  '달바바디미스트',
#  '글로우바디미스트',
#  '바디미스트추천',
#  '바디미스트',
#  '달바',
#  'ThinQ',
#  'LG씽큐',
#  '씽큐라서땡큐',
#  '박카스',
#  '학과피로',
#  'OO학과(자신의학과또는전공)',
#  '모카라디오',
#  '맥심모카라디오',
#  '맥심모카골드',
#  '팝업스토어',
#  '비듬샴푸',
#  '비디샴푸',
#  'TS샴푸',
#  'TS',
#  'TS비듬샴푸',
#  'TS비디샴푸',
#  'BD샴푸',
#  '두피샴푸',
#  '비듬관리',
#  '머리가가려울때',
#  '요즘단백질',
#  '농심켈로그',
#  '씨리얼',
#  '프로틴',
#  '프로틴그래놀라',
#  '그래놀라',
#  '단백질',
#  '미숫가루콩앤검정약콩',
#  '요거트큐브앤베리',
#  '신제품',
#  '신제품출시',
#  '파인애플',
#  '파인애플스트로우데코',
#  '과일',
#  'WTRD',
#  '위더로드',
#  '남자샌들',
#  '남자슬리퍼',
#  '여름슬리퍼',
#  '여름샌들',
#  '플립플랍',
#  '대상웰라이프',
#  '뉴케어',
#  '뉴케어액티브',
#  '사코페니아',
#  '식사대용식',
#  '운동스타그램',
#  '건강스타그램',
#  '롭스',
#  '플레이롭스',
#  '롭스핵인싸춤',
#  '홈솔루션',
#  '마이키파엑스트라파워',
#  '리퀴드전자모기향',
#  '굿나잇솔루션',
#  'ELLEFIT',
#  '엘르핏',
#  '엘르수영복',
#  'AR댄스페스티벌',
#  '유플러스5G',
#  'OOO(해당가수이름)',
#  '승무원미스트',
#  '미스트세럼',
#  '달바미스트세럼',
#  '달바미스트',
#  '승무원세럼',
#  '미스트추천',
#  '꼭써야한다면',
#  '나를위해지구를위해',
#  '불편한가방',
#  '가방스타그램',
#  '환경보호',
#  '재활용',
#  '에코백추천',
#  '풀무원의1',
#  'ad',
#  '유니클로감사제',
#  '멘토스',
#  '멘토스플레이그라운드',
#  '멘토스슬라이드',
#  '자이언트멘토스',
#  '메가박스코엑스',
#  '오레오데이',
#  '5월25일은오레오데이',
#  'OREODAY',
#  '5월25일',
#  '우리사이오래오래',
#  '오레오스노우스티커',
#  '#유료광고',
#  '#AD',
#  '스틱',
#  '오늘의언더암케어',
#  '롤온',
#  '향수',
#  '포스트',
#  '아몬드후레이크',
#  '아몬드후레이크이벤트',
#  '르크루제',
#  '르크루제시리얼볼',
#  '시리얼추천',
#  '어린이간식',
#  '아이들간식',
#  '시리얼볼',
#  '경품이벤트',
#  '에어리즘',
#  '에어리즘을입는100가지이유',
#  'loveAIRism',
#  '유니클로에어리즘',
#  'UNIQLOLifeWear',
#  'AIRism',
#  '에어리즘브리프',
#  '트란시노2',
#  '먹는기미치료제',
#  '민낯인생샷',
#  '8주프로젝트',
#  '보령제약',
#  '기미치료제',
#  '기미',
#  '피부고민',
#  '섀도우추천',
#  '더아이컬러',
#  '케이트섀도우',
#  '싱글섀도우',
#  '데일리섀도우',
#  '인생템',
#  '슈퍼샤프라이너EX',
#  'EX2.0',
#  '아이라이너추천',
#  '극세사아이라이너',
#  '아이라이너',
#  '잡스',
#  '모기',
#  '모기퇴치',
#  '데이트',
#  'ZAPS',
#  '해외여행',
#  '여름휴가',
#  '추천템',
#  '아웃도어미스트',
#  '버드와이저',
#  '버드500ML',
#  '버드빅보틀',
#  '얼리드링커',
#  '맛집',
#  '불금',
#  '꿀맛',
#  '먹스타그램',
#  '버쏘',
#  '만취각',
#  '꿀주',
#  '회식',
#  'MT',
#  '메이드바이유',
#  '이니스프리',
#  '스킨클리닉',
#  '마데카소사이드',
#  'made_by_you',
#  '마데카팩',
#  '미세먼지심한날',
#  '미세먼지필수템',
#  '여행가방싸기',
#  '실키오일세럼',
#  '극손상모환생',
#  '환생세럼',
#  '커리쉴',
#  '커리쉴클리닉',
#  '헤어에센스',
#  '헤어세럼',
#  '미용실추천템',
#  '원장님추천템',
#  'BeAKing',
#  '타투',
#  '타투전시회',
#  '자유가있는곳에',
#  '인사동',
#  '아라아트센터',
#  '전시회',
#  '문화생활',
#  '프리웨이브',
#  '대구카페추천',
#  '반월당카페',
#  '아인슈페너맛집',
#  '대구핫플',
#  '대봉동카페',
#  '삼덕동카페',
#  '봉산동카페',
#  '동성로카페',
#  'prewave',
#  '스트로베리콘',
#  '솔티카라멜콘',
#  '솔티카라멜맥플러리',
#  '아이스크림',
#  '청포도칠러',
#  '청포도',
#  '피크닉',
#  '봄나들이',
#  '소풍',
#  'illelan',
#  '일레란느',
#  '일레란느팝업',
#  '롯데백화점',
#  '일레란느주얼리',
#  '룸바이홈',
#  '룸바이홈침구',
#  '차렵이불',
#  '침구',
#  '롯데마트',
#  '롯데마트룸바이홈',
#  '알러지케어',
#  '안티알러지이불',
#  '알러지케어이불',
#  '가성비이불',
#  '체험단',
#  '넷플릭스',
#  '첫사랑은처음이라서',
#  '첫처음',
#  '럽스타그램',
#  '넷플릭스추천',
#  '클릭바틀',
#  '미정',
#  '에어아시아',
#  'KingofLCC',
#  '혁오',
#  '시크리스킨메이커',
#  '젤라또팩토리',
#  '띠부띠부팁패디',
#  '띠부띠부팁',
#  '젤라또팩토리패디',
#  '패디팁',
#  '패디',
#  '패디큐어',
#  '패디아트',
#  '발스타그램',
#  '젤패디',
#  '씨앤트리',
#  'seaNtree',
#  '찌릿찌릿썬더립스',
#  '립플럼퍼',
#  '립틴트',
#  '입술필러',
#  '입술보톡스',
#  '커피코카콜라',
#  '코크카페',
#  '코카콜라',
#  'coffeecocacola',
#  'cokecafe',
#  '달바선크림',
#  '선크림추천',
#  '촉촉한선크림',
#  '에센스선크림',
#  '뿌리는마스크팩',
#  '뿌마',
#  '달바뿌마',
#  '올리브영추천템',
#  '올리브영마스크팩',
#  '트롬건조후기백일장',
#  'LG스타일러',
#  '트롬건조는사랑입니다',
#  'LG트롬건조기',
#  'sponsored_by_엘지',
#  '득템',
#  '이벤트그램',
#  '쇼핑몰',
#  '블로그마켓',
#  '블로그공구',
#  '1인마켓',
#  '쇼핑몰제작',
#  '아임웹',
#  '합리적인',
#  '실용주의',
#  '더비슈즈',
#  '남자구두',
#  '남자로퍼',
#  '파스코로젠',
#  'Visa',
#  '비자',
#  'takeyourvisa',
#  '커플여행',
#  '우정여행',
#  '레몬',
#  '에어퀸',
#  '통기성',
#  '답답한생리굿바이',
#  '숨쉬는생리대',
#  '나노생리대',
#  '이하늬생리대',
#  '생리대',
#  '생리대추천',
#  '여성용품',
#  '제공받아리뷰',
#  'CHECKYOURVISA',
#  'TAKEYOURVISA',
#  '해시태그추가될예정',
#  'VISATIME',
#  'LETSVISA',
#  '비자카드',
#  '비자여행',
#  'VISA',
#  '대만여행',
#  '캘리포니아아몬드',
#  '아몬드',
#  '23알',
#  '마이뷰티시크릿',
#  '유어뷰티시크릿',
#  '뷰티간식',
#  '뷰티간식아몬드',
#  '다이어트',
#  '몸매관리',
#  '다이어트간식',
#  'TravelwithVisa',
#  'Visa카드',
#  '인증샷',
#  '인생샷',
#  '시그니처버거',
#  '트리플어니언버거',
#  '3가지어니언조합',
#  '시그니처버거신제품출시',
#  '여자친구',
#  '잼아저씨',
#  '개러지라이브',
#  'VLIVE',
#  'Kpop',
#  'idol',
#  '프링글스',
#  '프링글스미스터리맛',
#  '프링글스신제품',
#  '프링글스이벤트',
#  'PRINGLES',
#  'UniqloU',
#  '유니클로U',
#  'OOTD',
#  '26세럼',
#  'MTD26',
#  '고속볼륨',
#  '엠퀴리',
#  'MCURIE',
#  'm.curie',
#  'Idol',
#  '피넛버터오즈',
#  '멈출수없는아는맛',
#  '피넛버터오즈모먼트',
#  '오즈의나라',
#  '시리얼레시피',
#  '곡물시리얼',
#  '오즈링',
#  '오즈맨',
#  '신제품시리얼',
#  '시리얼이벤트',
#  '버드500ml',
#  '테스트',
#  '뷰티',
#  '크러쉬',
#  '김범수',
#  '젬스톤',
#  '너를만나',
#  '발라드',
#  '가수',
#  '가요',
#  '멜론',
#  '띵곡',
#  '홋카이도',
#  '커버',
#  '발라드추천',
#  '꿀보이스',
#  '음색깡패',
#  '라면 ',
#  '신상라면 ',
#  '풀무원 ',
#  '생면식감 ',
#  '생라면 ',
#  '건면 ',
#  '생라면',
#  '어그로 ',
#  '튀기지않은 ',
#  '원조 ',
#  '대세라면 ',
#  '생면부심 ',
#  '신라면건면 ',
#  '시조새 ',
#  '갓뚜기 ',
#  '웰컴',
#  '마스크팩',
#  '미세먼지',
#  '수분팩',
#  '안티에이징',
#  '콜라겐팩',
#  '하이드로겔팩',
#  '파이브피트',
#  '영화파이브피트',
#  '로맨스영화',
#  '영화추천',
#  '추천영화',
#  '유니클로진',
#  '유니클로청바지',
#  '네이쳐라이프',
#  '매콤꼬막과제육볶음',
#  '매콤불닭',
#  '매콤제육볶음',
#  '냉동안주',
#  '야식',
#  '간편하게',
#  '3분조리',
#  '전자레인지3분',
#  '5G는유플러스샵',
#  '오지는_어드벤처',
#  '오지는어드벤처',
#  '유플러스샵',
#  '유플러스샵_5G',
#  '하하',
#  '지조',
#  '라이브',
#  '자동차스타그램',
#  '쏘나타',
#  '더쏘나타라이브',
#  '오빠쏘나타',
#  '숨랩',
#  '숨랩마스크',
#  '숨쉬는초청정마스크',
#  '미세먼지마스크',
#  '쿨린',
#  '쿨린선풍기',
#  '허니콤선풍기',
#  'USB선풍기',
#  '탁상용선풍기',
#  '벌집선풍기',
#  '벌집망선풍기',
#  '회사선풍기',
#  '무자극바람',
#  '무자극선풍기',
#  '맥도날드디핑소스',
#  '이집소스잘하네',
#  '완딥',
#  '맥너겟',
#  '치즈스틱',
#  '에릭남',
#  '최욱',
#  '1가구1에릭남',
#  'ericnam',
#  '취향저격쏘나타',
#  '먼싱웨어',
#  'munsingwear',
#  '헬로아이엠피트',
#  '먼싱웨어피트',
#  '나이키',
#  '신발스타그램',
#  '피오니브라이트닝안티에이징크림',
#  '피오니크림',
#  '미백크림',
#  '20초크림',
#  '비타민B9톤업크림',
#  '톤업크림',
#  '수분톤업',
#  '썡얼크림',
#  '데저티카콜라겐모이스처라이징크림',
#  '수분크림',
#  '콜라겐크림',
#  '푸르지오',
#  '대우건설',
#  'PRUGIO',
#  '런칭파티',
#  '프리미엄파티',
#  '브랜드리뉴얼',
#  '2019푸르지오',
#  '슈레피',
#  'Surepi',
#  '슈레피샤워필터',
#  '샤워필터',
#  '스킨케어필터',
#  '콰트로필터',
#  '프리미엄샤워필터',
#  '더히스토리오부후',
#  'WHOO',
#  '비첩자생에센스',
#  '자생웨이브',
#  '로얄안티에이징',
#  '안티에이징에센스',
#  '필수에센스',
#  '자생력',
#  '1위에센스',
#  '롯데시네마',
#  '만우절',
#  '쿠폰사생대회',
#  '인증',
#  '유니클로CSW이벤트',
#  '오피스만렙',
#  '지금부터재테크는',
#  '엔화로갈아탄다',
#  '엔화재테크',
#  '엔화',
#  '환율',
#  '환전',
#  '안전자산',
#  '재테크',
#  '환테크',
#  '주식',
#  '일본주식',
#  '로망',
#  '영화로망',
#  '루나스틱파운데이션',
#  '루나',
#  '루나코어핏파운데이션',
#  '루나스틱파데',
#  '동서식품',
#  '도라지작두콩차',
#  '건강차',
#  '건강에좋은차',
#  '몸에좋은차',
#  '미세먼지에좋은차',
#  '환절기에좋은차',
#  '마시는차추천',
#  '미세먼지많은날도라지작두콩차',
#  '호흡기에좋은차',
#  '3355코로나',
#  '코로나',
#  'corona',
#  '코로나슬릭캔',
#  '슬릭캔',
#  'CoronaSleekcan',
#  '아이스버킷',
#  '코로나버킷',
#  '모임',
#  '코로나모임',
#  '코로나협찬',
#  '하루한줌아몬드',
#  '뷰티습관',
#  '취미생활',
#  '먼데이키즈',
#  '이진성',
#  '먼키',
#  '케이시',
#  '그때가좋았어',
#  '3월공연',
#  '콘서트',
#  '공연그램',
#  '콘서트그램',
#  '웨딩북',
#  '웨딩북청담',
#  '웨딩북스드메',
#  '엔조최재훈',
#  '최재훈드레스',
#  '엔조최재훈골드라벨',
#  '웨딩드레스',
#  '드레스투어',
#  '드레스피팅',
#  '웨딩사진',
#  '멋진남자',
#  '피톤케어',
#  '피톤케어맨',
#  '새해선물',
#  '새해선물추천',
#  '멘토스각',
#  '이럴때멘토스각',
#  'oo할때(상황묘사)',
#  'Refresh',
#  '츄파춥스',
#  '츄파펀콘서트',
#  '츄파아일랜드',
#  '세빛섬',
#  '자이언트롤리',
#  '자이언트츄파춥스',
#  '너랑코로나',
#  '화이트데이',
#  '아이마이밀',
#  '오트밀크',
#  '식사대용',
#  '한끼식사',
#  '다이어트식단',
#  '아웃도어맥주',
#  '코로나캔',
#  '오스바이오',
#  '오스케어',
#  '캡슐마스크',
#  '캡슐마스크팩',
#  '오스케어장미팩',
#  '바이오셀룰로오스',
#  '인생팩',
#  '케어놀로지',
#  '리블루미스트',
#  '리블루밸런싱크림인미스트',
#  '약산성미스트',
#  '크림미스트',
#  '윤광',
#  '안개분사',
#  '디트로네',
#  '디트로네라운지',
#  '송리단길',
#  '잠실카페',
#  '석촌카페',
#  '전동차',
#  '유아전동차',
#  '유모차',
#  '석촌호수',
#  '잠실브런치',
#  '석촌호수맛집',
#  '석촌호수카페',
#  '비오코스',
#  'BIOCOS',
#  '24K골드',
#  '24K골드퍼펙트',
#  '앰플팩',
#  '1일1앰플팩',
#  '멘토스릴레이',
#  '신세계사이먼아울렛',
#  '신세계사이먼부산',
#  '카페간식',
#  '커피타임',
#  '카페디저트',
#  '건강디저트',
#  'mbnyforum',
#  '엠비엔',
#  '와이포럼',
#  '하쿠나마타타',
#  '지금시작하라',
#  '두드림',
#  '영웅쇼',
#  '앵커쇼',
#  '두드림쇼',
#  '미래쇼',
#  '눈높이러닝센터',
#  '공부초능력',
#  '눈높이공부초능력',
#  '성장리포트',
#  '4력',
#  '자기주도학습',
#  '초등학원',
#  '공부방',
#  '자립학습',
#  '기초학력',
#  '소소풀',
#  '소나무팩폭',
#  '소소풀수풀마스크',
#  '텍스트가이드참고',
#  '오티스의비밀상담소',
#  'SexEducation',
#  'ShowUniqloU',
#  'UniqloLifeWear',
#  '현대백화점DUTYFREE',
#  '현대백화점면세점',
#  '면세점',
#  '슈레피워터탭',
#  '워터탭',
#  '스킨케어',
#  '수도꼭지필터',
#  '세면대필터',
#  '수도꼭지캠페인',
#  '2019설',
#  '설연휴',
#  '명절디저트',
#  '설날음식',
#  '질경이',
#  '질경이데일리에코아워시퓨어폼',
#  'Y존클렌저',
#  '여성청결제',
#  '여성청결제추천',
#  '여성청결제질경이',
#  '김소은',
#  '웹디자인',
#  '새해',
#  '목표',
#  '디자인포트폴리오',
#  '포트폴리오',
#  '디자이너',
#  'design',
#  '청바지',
#  '청바지코디',
#  '청바지추천',
#  '추후안내예정',
#  '눈높이CF영상',
#  '눈높이성장판',
#  '눈높이성장리포트',
#  '4력퀴즈이벤트',
#  '삼성전자',
#  '듀플로',
#  '레고듀플로',
#  '유아용레고',
#  '자동차세트',
#  '헬리콥터놀이',
#  '인공지능영화관',
#  '롯데시네마건대',
#  '롯데시네마건대입구',
#  '건대입구',
#  '립스틱',
#  '뷰티스타그램',
#  '유나뷰스터',
#  '유나',
#  '뷰티유튜버유나',
#  '뷰티클라우드유나',
#  '이너뷰티',
#  'LG',
#  '엘지',
#  '디오스',
#  'DIOS',
#  '주방스타그램',
#  '어디에살든',
#  '나답게살자',
#  '직방이벤트',
#  '아이오페',
#  '컬러핏립스틱',
#  '아이오페컬러핏립스틱',
#  '신민아립스틱',
#  '컬러핏립스틱글로우',
#  '고발색',
#  '쫀쫀밀착',
#  '맑은발색',
#  '촉촉광택',
#  '유세린',
#  '매끈탄탄',
#  '듀얼세럼',
#  '나이트케어추천',
#  '듀얼액션',
#  '차오르는수분',
#  '탱탱해진피부',
#  '피부결개선',
#  '저자극각질케어',
#  '하이알루론나이트필링앤세럼',
#  '육시칼퇴',
#  '육칼',
#  '육시칼퇴챌린지',
#  '풀무원육칼',
#  '육개장칼국수',
#  '틱톡',
#  '새해계획',
#  '신년계획',
#  '2019년계획',
#  '2019년목표',
#  '야놀자',
#  '인싸춤',
#  '놀춤',
#  '아리얼',
#  'ariul',
#  '아리얼마스크팩',
#  '무드메이커',
#  '무드메이커마스크',
#  '디데이마스크',
#  '마스크시트',
#  '떡볶이',
#  '죠스떡볶이',
#  '죠스신메뉴',
#  '국물떡볶이',
#  '그대이름은장미',
#  '무대인사',
#  '영화관람',
#  '배꼽빠짐',
#  '사랑해요장미',
#  '1월16일대개봉',
#  '시사회',
#  '말할수있는비밀',
#  '스피치',
#  '말하기',
#  '취업',
#  '베스트셀러',
#  '온라인서점3개중택1',
#  '데상트',
#  '백팩',
#  '배틀',
#  '신발',
#  '데상트터보',
#  '유리프',
#  'youlief',
#  '출근토너',
#  '스킨토너',
#  '수분토너',
#  '대용량토너',
#  '에센스토너',
#  '인생토너',
#  '환절기스킨케어',
#  '출근러',
#  '퇴근준비',
#  '뷰티일상',
#  '동안피부',
#  '촉촉한피부',
#  '촉촉보습',
#  '1분긴급수분',
#  '역삼동고시원',
#  ' 역삼동원룸',
#  ' 작심하우스',
#  ' 직장인원룸',
#  ' 강남구원룸',
#  '보드게임영상통화',
#  'WAVE',
#  '할리갈리',
#  '캐치마인드',
#  '추천앱',
#  '하남스타필드',
#  '실종아동찾기',
#  '조하늘',
#  '최진호',
#  '박동은',
#  '실종아동찾기센터182',
#  '세상에서가장큰아이',
#  '골든그래놀라',
#  '골든그래놀라레드빈그린티',
#  '녹차시리얼',
#  '포스트시리얼',
#  '그래놀라시리얼',
#  '아침식사대용',
#  '시리얼신제품',
#  '쇼케이스',
#  '클룩',
#  '클룩점프',
#  'Klook',
#  '여행을클룩하다',
#  '도시명(여행지)',
#  '피자헛4030랩',
#  '피자헛모델',
#  '피자헛광고',
#  'pizzahut',
#  '피부과쿠션',
#  '레노덤쿠션',
#  '지속력갑',
#  '재생비비',
#  '재생쿠션',
#  '물광메이크업',
#  '레노덤',
#  '데이롱비비크림',
#  '비비크림',
#  '비비쿠션',
#  '크리스마스선물',
#  '연말선물',
#  '선물추천',
#  '선물',
#  '핸즈업커피',
#  '위례맛집',
#  '에그와플',
#  '와플맛집',
#  '딸기와플',
#  '겉바속촉',
#  '밀크티',
#  '커피맛집',
#  '놀이터브릭박스',
#  '브릭박스',
#  '대교',
#  '성장리포트인터뷰영상',
#  'Ulike',
#  'ULikeHalloQueen',
#  'HorrorQueen',
#  'HalloweenMakeUp',
#  '눈높이4력영상',
#  '어린이집선생님',
#  '감사합니다',
#  '제2의엄마',
#  '보육교사',
#  '존경',
#  '너도나도감사한마음',
#  '힘내세요',
#  '이벤트홍보',
#  '영양식',
#  '근감소',
#  '육아맘일상',
#  '맘스타그램',
#  '육아몸매관리',
#  '콘푸라이트',
#  '오곡코코볼',
#  '새로워진포스트',
#  'LG코드제로A9물걸레',
#  'LG코드제로A9',
#  '무선청소기',
#  '무선청소기추천',
#  '물걸레청소기',
#  'LG무선청소기',
#  '혼수선물',
#  '이사선물',
#  '득템찬스',
#  '할인이벤트',
#  '동원참치',
#  '쿡캔55가지레시피',
#  '반찬레시피',
#  '아이반찬',
#  '저녁메뉴',
#  '육아스타그램',
#  '요리레시피',
#  '집밥',
#  '마약왕',
#  '송강호',
#  '조정석',
#  '배두나',
#  '영화스타그램',
#  '12월19일대개봉',
#  '킨트',
#  '킨트주얼리',
#  'KINT',
#  '킨트레드박스',
#  '오르빗컬렉션',
#  '여자친구선물',
#  '데일리목걸이OR데일리귀걸이(해당제품의해시태그)',
#  '포인트목걸이OR포인트귀걸이(해당제품의해시태그)',
#  '무선물걸레청소기',
#  '인테리어',
#  '예쁜청소기',
#  '브런치카페',
#  '카페투어',
#  '연말모임',
#  '신년모임',
#  '단체예약',
#  '말리부',
#  '시승행사',
#  'THENEWMALIBU',
#  '쉐보레',
#  'Chevrolet',
#  '비교시승',
#  '중형세단',
#  '차스타그램',
#  'Carstagram',
#  '크리스마스',
#  '아임리얼',
#  '순수착즙',
#  '리얼과즙',
#  '천연과일주스',
#  'imreal',
#  'realjuice',
#  '손상케어',
#  '현실주의스킨케어',
#  '코덕',
#  '앰플',
#  '재생앰플',
#  'kbeauty',
#  '뉴트리탄앰플',
#  '리얼후기',
#  '#HERA',
#  '헤라',
#  '로지사틴크림',
#  '헤라클렌징티슈',
#  '럭셔리티슈',
#  '완결크림',
#  '수분결크림',
#  '디자인어워드',
#  '메이크업필러',
#  '벨로테로',
#  '메이크업쇼',
#  '멀츠코리아',
#  'Merz',
#  'serendipityjourney',
#  'MASJ',
#  '세렌디피티',
#  '오이보스',
#  '베이비오일',
#  '꿀잠오일',
#  '베이비마사지',
#  '꿀잠',
#  '통잠',
#  '스킨미소',
#  '개기름지우개',
#  '노세범',
#  '기름종이',
#  'skinmiso',
#  '아몬드뷰티스튜디오',
#  '타임스퀘어',
#  'N서울타워',
#  '남산타워',
#  '산타클룩스',
#  '도시명(여행했던 지역명)',
#  '더참치togo',
#  '요리스타그램',
#  '즉석요리',
#  '혼밥',
#  '건강한간식',
#  '운동간식',
#  '저칼로리',
#  '헬스',
#  '간편식',
#  '다이어트음식',
#  '자기관리',
#  '패션',
#  '참치다이어트',
#  '파우치참치',
#  '동서벌꿀',
#  '꿀바른생활',
#  '겨울아이템',
#  '100퍼센트꽃꿀',
#  '꿀',
#  '벌꿀',
#  '꿀레시피',
#  '꿀활용법',
#  '사전포스팅/방문인증 포스팅 별 해시태그가 다르니 가이드 참고하여 삽입해 주세요!!',
#  '칼퇴는권리',
#  'StellaArtois',
#  '아침간식',
#  '저녁간식',
#  '출근길',
#  '퇴근길',
#  '포스트그래놀라',
#  '그래놀라센서리지퍼백',
#  '센서리지퍼백',
#  '빙그레',
#  '펫밀크',
#  '에버그로',
#  '빙그레펫밀크',
#  '에버그로펫밀크',
#  '빙그레에버그로펫밀크',
#  '달바세럼',
#  '항산화세럼',
#  '항산화아이크림',
#  '현대홈쇼핑',
#  'dalba',
#  '현대홈쇼핑_달바',
#  '달바홈쇼핑',
#  '버츠비',
#  '홀리데이에디션',
#  '올리브영',
#  '@hddfs.official',
#  '금손포토스팟10',
#  '장소명(예-삼성역포토스팟 그대로복사하지마세요)',
#  '프리미엄독서실',
#  ' 독서실추천',
#  ' 작심독서실',
#  ' 공스타그램',
#  ' 공부인증',
#  '작심독서실OOO점',
#  'AHC',
#  '미니멀10',
#  'AHC미니멀10',
#  'AHC워터리에센스',
#  '민감성피부',
#  '시카케어',
#  '병풀추출물',
#  '저자극',
#  '뷰스타그램',
#  'MAKEMERARE',
#  'RAREKIND',
#  '레어카인드',
#  'BERAREKIND',
#  'lipcraver',
#  '립크레이버',
#  '립추천',
#  '신상립',
#  '솔어바웃',
#  'soleabout',
#  '여자구두',
#  '롯데월드몰',
#  '#팝업인증샷',
#  '뽐뿌뽐뿌',
#  'TEAM다운',
#  'GUOUTER',
#  'GUstyle',
#  'GU데일리룩',
#  'GUKorea',
#  'GUAD',
#  'GU광고',
#  'TEAM울',
#  '제품마다 상이합니다!! 텍스트 가이드를 참조해 주세요!',
#  '대박이벤트',
#  '풀무원아임리얼',
#  '아임리얼굿즈',
#  '아임리얼에코백',
#  '아임리얼링거치대',
#  '연말선물추천',
#  '프레시코드',
#  '프코',
#  '프코샐러드',
#  '샐러드맛집',
#  '샐러드추천',
#  '프코한끼',
#  '새벽배송',
#  '샐맥',
#  '식단일기',
#  '감사제',
#  '슈퍼킵라이너',
#  '처음그대로keep',
#  'NoMoreTouch',
#  '히로인메이크스무스리퀴드라이너슈퍼킵',
#  '워터프리카라',
#  '바를땐_워터프루프',
#  '지울땐_리무버프리',
#  '히로인메이크어드밴스드필름마스카라',
#  '마스카라',
#  '피키이터',
#  '피키이터역삼',
#  '강남맛집',
#  '역삼맛집',
#  '역삼역',
#  '가성비갑',
#  '슬리핑뷰티112',
#  '매일밤피부잠금',
#  '예뻐지잠',
#  '쿨쿨케어',
#  '인싸밤케어',
#  '숙면피부',
#  '슬리핑뷰티템',
#  '슬리핑뷰티템추천',
#  '아자르',
#  '요즘핫한어플',
#  '꿀잼',
#  'Azar',
#  '영화간식',
#  '영화관간식',
#  '최애간식',
#  '빙그레슈퍼콘',
#  '슈퍼콘초코',
#  '슈퍼콘바닐라',
#  '슈퍼콘광고',
#  '겨울이',
#  '코아페',
#  '코오롱몰아우터페스티벌',
#  '럭키슈에뜨',
#  '설리캔디코트',
#  '겨울인싸되기',
#  '소원슈에뜨',
#  '소원인형',
#  '일렉트로룩스',
#  '북유럽포트',
#  '2도디테일',
#  '전기포트',
#  'byseries',
#  '247덕다운롱패딩',
#  '24시간7일입어도편한',
#  '247',
#  '데일리웨어',
#  '아기띠',
#  '아기띠추천',
#  '아기띠패션',
#  ' 힙시트아기띠',
#  '특허받은아기띠',
#  '다이치광고',
#  '힙시트',
#  '힙시트추천',
#  '힙시트아기띠',
#  '완전편안한힙시트',
#  'NIVEA',
#  '믹스미',
#  '니베아믹스미',
#  '바디앤핸드크림',
#  '나만의향나만의색깔',
#  'heattech',
#  '유니클로히트텍',
#  '히트텍',
#  '한율',
#  '달빛유자',
#  '달빛다방',
#  '달빛유자수면팩',
#  'HANYUL',
#  '익선동카페',
#  '카페스타그램',
#  '그림의힘',
#  '그림의힘2',
#  '수능선물',
#  '수능',
#  '수능특강',
#  '합격기원',
#  '책스타그램',
#  '북스타그램',
#  '맥도날드시그니처멤버스',
#  '인마이백',
#  '최애템',
#  '제품브랜드명을입력해주세요',
#  '받으신제품명을입력해주세요',
#  '어딕션',
#  '이효리',
#  '이효리화보',
#  '어딕션윈터',
#  '시누아즈리',
#  '레드중독',
#  '엠파이어패션',
#  '더아이섀도우128',
#  '레드범벅',
#  '엠프레스오키드',
#  '리퀴드아이라이너13',
#  '레드썬',
#  '코오롱아우터페스티벌',
#  '브랜드명을입력해주세요',
#  '제품명을적어주세요',
#  '오레오오즈',
#  '초코시리얼',
#  '키덜트',
#  '소프트크림치크',
#  '소크치',
#  '블러셔',
#  '블러셔추천',
#  '에센스',
#  '남성에센스',
#  '남자에센스',
#  '군용',
#  '군인',
#  '군인선물',
#  '남편선물',
#  '남자친구선물',
#  '레드칙',
#  '요즘은이런식',
#  '어성초크림',
#  '진정케어',
#  '트러블케어',
#  '보습크림',
#  '겨울필수템',
#  '맑은피부',
#  '헤이네이처',
#  '미쓰백',
#  '한지민',
#  '영화리뷰',
#  '사회적메세지',
#  '응원합니다',
#  '감동',
#  '희망',
#  '추천',
#  'gd11',
#  '지디일레븐',
#  '지디11',
#  '시카셀',
#  '줄기세포',
#  '줄기세포화장품',
#  '미백주름개선',
#  '크림추천',
#  '토너추천',
#  '#WISHtoThinQ',
#  '#LG씽큐',
#  '#LGThinQ',
#  '#인공지능가전',
#  '#제작비지원 by #LG전자',
#  '아침에주스유기농',
#  '아침에유기농',
#  '아침에주스오가닉',
#  '유기농주스',
#  '건강주스',
#  '오렌지주스',
#  '포도주스',
#  '토마토주스',
#  '아침에주스',
#  '옵티프리 ',
#  '알콘 ',
#  '렌즈세척액 ',
#  '깐깐한렌즈관리용액 ',
#  '따가움없이 ',
#  '전세계판매1위 ',
#  '수분막형성 ',
#  '한달렌즈 ',
#  '에어렌즈 ',
#  '콘택트렌즈',
#  '삼분의일매트리스',
#  '삼분의일부산',
#  '온도조절포트',
#  '분유포트',
#  '커피포트',
#  '랩노',
#  '이데베논세럼',
#  '노란탄력포텐',
#  '유해성분NO',
#  '기초화장품',
#  '세럼추천',
#  '탄력',
#  '이데베논',
#  '지퍼락',
#  '지퍼락이지오픈탭',
#  '본인의 활용방법과 관련된 해시태그(여행준비등)',
#  '혜화',
#  '별반짝이는꽃',
#  '나의찬란했던순간_혜화',
#  '정은지',
#  'ZNE',
#  'FASTRELEASE',
#  '준비된단한번의움직임',
#  '브라운면도기',
#  '브라운시리즈9',
#  'AI면도기',
#  '전기면도기추천',
#  '남자면도기추천',
#  '전기면도기순위',
#  '면도기선물',
#  '그루밍족',
#  'giftfromBraun',
#  '브라운제공',
#  '브라운시리즈7',
#  '웰라쥬',
#  'Wellage',
#  'HA원데이키트',
#  '광채앰플',
#  '하지원',
#  '피부탄력',
#  '스페셜케어',
#  '웰라쥬지원제품',
#  '후기는솔직하게',
#  '영화휴게소 ',
#  '재희',
#  'VOD개봉',
#  '극장동시',
#  '공포영화',
#  '양수빈',
#  '영화휴게소',
#  '대상',
#  '면역력',
#  '클로렐라',
#  '면역엔클로렐라',
#  'HealthyGreen',
#  '메르스',
#  '메르스조심',
#  '메르스예방',
#  '환절기',
#  '마이밀',
#  '아침대용식',
#  '아침대용',
#  '속편한식사대용식',
#  '미래형식사',
#  '건강식단',
#  '유당불내증',
#  '셀프사진관',
#  '셀프촬영',
#  '셀프스튜디오',
#  '인생화보',
#  '커플사진',
#  '가족사진',
#  '우정사진',
#  '데상트영애슬리트',
#  '깔라만시패드',
#  '잡티케어',
#  '비타민듬뿍',
#  '피부톤업',
#  '노폐물배출',
#  '윤기촉촉',
#  '간편관리',
#  '뷰튜버추천 ',
#  '레고',
#  '영유아를위한레고',
#  '추석선물',
#  '아이선물',
#  '추석지퍼락',
#  '추석음식준비',
#  '리큅',
#  '초고속블렌더',
#  '식품건조기',
#  '프리미엄주방가전',
#  '리큅이벤트',
#  '행운의1인',
#  '결정흔들리지않고마음먹은대로',
#  '결정책',
#  '띵작',
#  '결정습관',
#  '결정잘하는법',
#  '프로결정러',
#  '책추천',
#  '핵꿀잼',
#  '핵공감',
#  '헛개초코밀크',
#  '초코우유',
#  '숙취해소',
#  '숙취해소음료',
#  '달콤한해장엔',
#  '해장',
#  '손글씨_응원릴레이',
#  '제주동중_사이클팀',
#  '손글씨',
#  '캘리',
#  '캘리그라피',
#  '디오스냉장고',
#  'LG전자',
#  '다이슨슈퍼소닉',
#  '다이슨드라이기',
#  '헤어스타일링',
#  '아이오페시카크림',
#  '정답시카',
#  '노답피부',
#  '민감피부',
#  '더마리페어시카크림',
#  '진정크림',
#  '순한화장품',
#  '시카크림',
#  '시카크림효능',
#  '응원쓰기_릴레이',
#  '제주동중싸이클팀',
#  '샹프리',
#  '샹프리마린쥬얼캡슐',
#  '페이스오일',
#  'harrods',
#  'harrodsbeauty',
#  'shangpree',
#  '마린쥬얼시트마스크',
#  '이클립스',
#  '이클립스민트',
#  '이클립스캔디',
#  '민트',
#  '민트캔디',
#  '일상템',
#  'CU에서구매',
#  '오늘의건강',
#  '오늘의장',
#  '오늘템',
#  '에잇템',
#  '책상위작은밭',
#  '책상위작은밭양배추사과즙',
#  '책밭즙',
#  '양배추사과즙',
#  '양배추즙',
#  '양사즙',
#  '즙',
#  '즙스타그램',
#  '양배추즙추천',
#  '위건강',
#  '책상위작은밭호박즙',
#  '호박즙',
#  '붓기',
#  '붓기빼기',
#  '붓기제거',
#  '부종',
#  '부기',
#  '호박즙추천',
#  '차홍',
#  '건강한모발',
#  '콘푸라이트사랑충전소',
#  '원조시리얼',
#  '가족시리얼',
#  '랩노쉬',
#  'Labnosh',
#  '이것이식사다',
#  'atem',
#  '프로틴바',
#  '그로서리서울',
#  '밤간식',
#  '죽',
#  '단호박죽',
#  '호박죽',
#  '삼계죽',
#  '육개장죽',
#  '인생책',
#  '마운틴듀',
#  '마듀',
#  '설화수',
#  '자음생에센스',
#  '자음생',
#  '인삼에센스',
#  '캡슐에센스',
#  '탄력각',
#  '록시땅',
#  '이모르뗄리셋세럼',
#  'HelloGoldMorning',
#  'MyResetMoments',
#  '푹못잔건비밀',
#  'TimeToReset',
#  '자연주의세럼',
#  '금모닝세럼',
#  '카스랑놀자',
#  'CBP2018',
#  'CBP',
#  '카스블루플레이그라운드',
#  'CASSBLUEPLAYGROUND',
#  '카스',
#  'Cass',
#  '카스프레시',
#  'CassFresh',
#  '블루모지',
#  '하이네켄',
#  'heineken',
#  '월드클래스',
#  'worldclass',
#  '펜타포트락페스티벌',
#  '펜타포트',
#  '2018펜타포트',
#  'LIVEYOURMUSIC',
#  '#프로틴바',
#  'apmall',
#  '아모레퍼시픽몰',
#  '아몰',
#  '인마이백릴레이',
#  '인마이파우치',
#  '아몰이벤트',
#  'IGO신남',
#  '스튜디오S',
#  '인생프사',
#  ' 인생샷',
#  ' 신세계면세점강남점',
#  ' 신세계면세점',
#  ' StudioS',
#  '신세계면세점강남점',
#  'StudioS',
#  '매그넘',
#  '매그넘아이스크림',
#  '매그넘플레져스토어',
#  '진한즐거움에빠지다',
#  '강남역카페',
#  '강남역맛집',
#  '매그넘서울',
#  'MAGNUMSEL',
#  '터치후레쉬',
#  '화장실',
#  '화장실냄새제거',
#  '화장실방향제',
#  '향기스타그램',
#  '셀루닉',
#  '래디언스퍼밍크림',
#  '주름개선',
#  '광채탄력크림',
#  '광탄력크림',
#  '주름개선화장품',
#  'CU',
#  '목요일발표예정',
#  '#언더100',
#  '아워홈',
#  '윤아더하기',
#  'DB다이렉트',
#  '유플러스알뜰모바일',
#  'U알뜰모바일',
#  '홈플러스요금제',
#  '알뜰폰',
#  '요금제추천',
#  '통신비',
#  '알뜰폰요금제',
#  '홈플러스요금',
#  '홈플러스신제품',
#  '하임셰프',
#  '뽀송뽀송',
#  '뽀드득',
#  '살균',
#  '멸균',
#  '주방',
#  '주방가전',
#  '비플랫',
#  '세상편한피부관리',
#  '슬리핑마스크',
#  '피부재생',
#  '시카성분',
#  'beflat',
#  '시카1000ppm',
#  '꿀광피부',
#  '카페스노우',
#  '디저트',
#  '편의점디저트',
#  'haveanicesnow',
#  '홍대냉장고',
#  '홍대핫플',
#  '던킨',
#  '던킨도넛',
#  '콜드브루',
#  '핵꿀맛',
#  '당충전',
#  'JMT',
#  '야놀자이벤트',
#  '초특가야놀자',
#  '너도하니나도하니',
#  '스노우',
#  '스노우이벤트',
#  '블루문',
#  '블루문풀파티',
#  'bluemoon',
#  '블루문맥주',
#  'Hi5페스티벌',
#  '반얀트리',
#  '풀파티',
#  '반얀트리풀파티',
#  '블루문파티',
#  '카스미니캔',
#  'CassMiniCan',
#  '카스프레시250',
#  '점심시간엔CassMini',
#  '원샷캔',
#  '작으니까좋아',
#  '비브라스쇼케이스',
#  '비브라스',
#  'vivlas',
#  '보아',
#  '추자현마스크팩',
#  '보아립밤',
#  'BOA',
#  '보아공연',
#  '보아마스크팩',
#  '키썸',
#  ' 100%',
#  ' under100',
#  ' 아워홈',
#  ' 오늘부터내밥',
#  '#유세린',
#  '#eucerin',
#  '#더모퓨리파이어',
#  '#오일컨트롤',
#  '#트러블독립선언',
#  '대구치맥페스티벌',
#  '대구치맥',
#  'chimacfestival',
#  '치킨앤카스',
#  '치킨엔카스',
#  '카스브랜드데이',
#  'CASSBrandDay',
#  '치킨에는Cass',
#  '알뜰모바일',
#  'GS25요금제',
#  'GS25추천',
#  'GS25요금',
#  '랄라블라요금제',
#  '랄라블라요금',
#  '랄라블라신제품',
#  '베이비프렌즈',
#  '픽처하우스',
#  '베이비프렌즈추천상품',
#  '유아용추천도서',
#  '신개념영상통화',
#  'Wave',
#  '우리가노는법',
#  '웨이브',
#  '최대8명',
#  '꿀팁',
#  '뻬딱구두',
#  '수제화브랜드',
#  '디자이너슈즈',
#  '맞춤수제화',
#  '이태리천연가죽',
#  '성수동수제화',
#  '프레시코드신메뉴',
#  '분짜샐러드',
#  '쉬파샐러드',
#  '프코스팟',
#  '다이어터',
#  '알페신',
#  'alpecin',
#  '남자샴푸',
#  '독일샴푸',
#  '독일의기술력',
#  'eucerin',
#  '더모퓨리파이어',
#  '오일컨트롤',
#  '트러블독립선언',
#  '화산송이',
#  '얼굴청소',
#  '100인체험단',
#  '수퍼체험단',
#  '화산송이체험단',
#  '모공청소기',
#  '이니스프리모공팩',
#  '모공팩',
#  '미샤',
#  '미샤파우치인클리어백',
#  '미샤PVC백',
#  '얼청타임',
#  '아묻따모공팩',
#  '바나나맛우유',
#  '바나나맛우유뽑기',
#  '함께놀아요',
#  '빙바',
#  '단지우유',
#  '프레민트치약',
#  '프레민트',
#  '치약',
#  '치약추천',
#  '프리미엄치약',
#  '민트치약',
#  '집들이선물',
#  '구취제거',
#  '이니스프리슈퍼푸드',
#  '슈퍼푸드소확행',
#  '슈퍼푸드블루베리라인(제품에따라달라질수있음)',
#  '박나래클로렐라',
#  '면역력발사',
#  '박나래',
#  '톰크루즈',
#  '생일',
#  '미션임파서블',
#  '미션임파서블폴아웃',
#  '본인이수령한제품명을입력해주세요',
#  '티오피',
#  '트리플에스프레소라떼',
#  '일상탈출',
#  '휴가',
#  '발렌타인파이니스트',
#  '발렌타인',
#  '하이볼',
#  '발렌타인파이니스트하이볼패키지',
#  '술스타그램',
#  '바캉스',
#  '베링',
#  '맥심티오피',
#  '나만의티오피',
#  '티오피익스플로링',
#  '티오피10주년',
#  '시그니처블랙',
#  '맥심플랜트',
#  '티오피팝업스토어',
#  '맥심플랜트팝업스토어',
#  '한남동핫플',
#  '안된다는생각',
#  '뒤집어버려',
#  '월드컵공식맥주',
#  '2018FIFA러시아월드컵',
#  '뒤집어바',
#  'Worldcup',
#  '홈카페',
#  '베버시티스틱',
#  '베버시티',
#  '녹차라떼',
#  '고구마라떼',
#  '딸기스무디',
#  '망고스무디',
#  '홈메이드',
#  '세미기업',
#  '뽑픽',
#  '그랩픽',
#  'grabpic',
#  '필카',
#  '필름감성',
#  '사진앱',
#  '필름앱',
#  '밀착사진',
#  '디지털필름',
#  '데이24',
#  '본인의컨셉해시태그(예:심쿵24관종24일상24등)',
#  '#프레민트치약',
#  '#프레민트',
#  '#치약',
#  '#치약추천',
#  '#프리미엄치약',
#  '#민트치약',
#  '#집들이선물',
#  '#구취제거',
#  '#여행',
#  '#선물',
#  '쉬어래스팅',
#  '쉬어래스팅룩',
#  '쉬어래스팅젤쿠션',
#  '설화수쿠션',
#  '쉬어래스팅쿠션',
#  '보송화사',
#  '쉬어래스팅메이크업',
#  '송혜교메이크업',
#  '올때메로나칸탈루프',
#  '올때메로나',
#  '메로나칸탈루프',
#  '메로나',
#  '올때메로나튜브',
#  '메로나튜브',
#  '수아도르',
#  '친절한브러씨',
#  '이사배',
#  '메이크업',
#  '브러쉬',
#  '핑덕',
#  '메이크업브러쉬',
#  'SOOADOR',
#  'RISABAE',
#  '인화사진',
#  '인화',
#  '사진',
#  'DAY24',
#  '사진선물',
#  '친구24심쿵24관종24중본인에게해당하는미션해시태그',
#  '야놀자초특가',
#  '패러디',
#  '야놀자하니',
#  '하니',
#  '인생경기공유이벤트',
#  '알페신이벤트',
#  'All_About_Steak',
#  '스테이크',
#  '팩스테이크',
#  '홈스테이크',
#  '홈스',
#  '헤비시즈닝스테이크',
#  '돈스파이크',
#  '먹방',
#  '이마트',
#  'emart',
#  '티오피10주년축하해요',
#  '원빈',
#  '홈핏',
#  '홈트레이닝',
#  '홈트',
#  '홈트하는여자',
#  '운동하는여자',
#  '다이어터소통',
#  '홈요가',
#  '홈트족',
#  '홈피티',
#  '좋은것은오래갔으면좋겠습니다',
#  '버넬',
#  '섬유유연제',
#  'vernel',
#  '버넬10주간의향기',
#  '10글자열정댓글이벤트',
#  '바이탈뷰티',
#  '메타그린',
#  '먹방스타그램',
#  '입은즐겁게몸은가볍게',
#  'PK마켓',
#  '수제맥주',
#  'IPA',
#  '라거',
#  '맥주',
#  '화수브루어리',
#  '버드나무브루어리',
#  '크래프트루트',
#  '플레이그라운드',
#  '속초IPA',
#  '#LGTHINQ',
#  '#IMAGINEYOURDAY',
#  '#전시',
#  '#성수',
#  '#바이산',
#  '#BAESAN',
#  '개들의섬',
#  '6월21일개봉',
#  '웨스앤더슨',
#  '외에2개이상자유롭게추가해주세요',
#  ' #IMAGINEYOURDAY',
#  ' #전시',
#  ' #성수',
#  ' #바이산',
#  ' #BAESAN',
#  '',
#  '#씽큐',
#  ' #엘지씽큐',
#  ' #씽큐전시',
#  '친구24심쿵24관종24중본인의미션에해당하는것1',
#  '블루문위크',
#  'bluemoonweek',
#  '블루문생맥주',
#  '오렌지가니쉬',
#  'bluemoonbeer',
#  '#블루문',
#  ' #bluemoon',
#  ' #블루문위크',
#  ' #bluemoonweek',
#  ' #블루문맥주',
#  ' #블루문생맥주',
#  ' #오렌지가니쉬',
#  ' #bluemoonbeer',
#  '6월21일대개봉',
#  '댕댕이',
#  '졸귀',
#  '소장각',
#  '하비풀',
#  '유미의세포들',
#  '미니어처',
#  '미니어처하우스',
#  '취미스타그램',
#  '취미클래스',
#  '출출이콘테스트',
#  '식기건조기',
#  '식기살균건조기',
#  '식기건조대',
#  '젖병소독기',
#  '주방인테리어',
#  '더마코스메틱',
#  '약국용화장품',
#  '프라우드메리',
#  '메리를만나면프라우드해집니다',
#  '저자극화장품',
#  '보습립오일',
#  '식물성오일',
#  '샐러드',
#  '샐러드배달',
#  '프레시코드샐러드',
#  '잔류염소',
#  '스킨케어워터탭',
#  'surepi',
#  'skincare',
#  'beauty',
#  'cosmetics',
#  'water',
#  '화장품',
#  '모든문제는물때문이었는지몰라',
#  '뷰티인스타그래머',
#  '인플루언서',
#  '크리에이터',
#  'beringtime',
#  '2018visafootballnight',
#  'VisaKorea',
#  '2018VISAFOOTBALLNIGHT',
#  '달품애',
#  '달품애생리대',
#  '유기농',
#  '유기농생리대',
#  '유기농생리대추천',
#  '안전한생리대',
#  '낮보단밤에더보고싶어',
#  '김작가의이중생활X더부스',
#  '국민IPA',
#  '김작가의이중생활',
#  'Beringtime',
#  '오직그대만',
#  '누가크래커',
#  '에그롤',
#  '합정맛집',
#  '부천맛집',
#  '압구정로데오맛집',
#  '일산맛집',
#  '소금커피',
#  '대만수제디저트',
#  '그대만의대만',
#  '독전',
#  '영화',
#  '갓띵작',
#  '존잼',
#  '심플리스무스',
#  '티오피심플리스무스',
#  '스무스하게잘넘겼어',
#  '스무스하게넘겨툰',
#  '스무스키트',
#  '심플리스무스키트',
#  '드립배틀',
#  '쿠알라룸푸르',
#  'airasia',
#  'GO100ASIA',
#  '아시아를자유롭게',
#  '쿠알라룸푸르를자유롭게',
#  '뷰티피플',
#  'BEAUTYPEOPLE',
#  '철벽녀쿠션',
#  '철벽녀텐션쿠션',
#  '철벽녀쿠션2',
#  '텐션쿠션',
#  '철벽녀엔티크',
#  '쿠션파운데이션',
#  '쿠션추천',
#  '마늘이의일기',
#  '브라벡토',
#  'BRAVECTO',
#  '12주간의사랑',
#  '진드기예방',
#  '버넬10주',
#  '해초마스크',
#  '진정팩',
#  '스피루리나',
#  '모델링팩',
#  '아이마스크',
#  '포키',
#  'pocky',
#  'UT',
#  'sharehappiness',
#  '과자',
#  'snack',
#  'fashion',
#  'ootd',
#  'pockyUT',
#  '밸런스온',
#  '마동석',
#  '자세교정',
#  '방석',
#  '베개',
#  '밸런스온시트',
#  '밸런스온필로우',
#  '마동석방석',
#  '인스타툰',
#  '썬비',
#  '그림비',
#  'TOP',
#  'U플러스알뜰모바일',
#  '무제한데이터',
#  '썸부스터',
#  '스테이얼',
#  'STAYERE',
#  '토일렛퍼퓸',
#  '시크릿커버퍼퓸',
#  '스테이얼핑크바디워시',
#  '핑크바디워시',
#  '바디브러쉬',
#  '육아',
#  '육아소통',
#  '육아템',
#  '육아맘',
#  '신생아유산균',
#  '유산균추천',
#  '아기유산균',
#  '드시모네',
#  '드시모네베이비',
#  '내추럴더마프로젝트 ',
#  '스킨케어 ',
#  '기초화장품 ',
#  '수분크림 ',
#  '재생크림 ',
#  '톤업크림 ',
#  '데저티카콜라겐모이스처라이징크림 ',
#  '시카바이오플라센타크림 ',
#  '어린이날',
#  '유아선물',
#  '아미오그레인프리',
#  '아미오',
#  '풀무원아미오',
#  '그레인프리',
#  '고양이사료',
#  '냥스타그램',
#  '#작가의탄생',
#  '#책만들기',
#  '#그림책',
#  '#작가',
#  '#어린이작가',
#  '#그림책만들기',
#  '#그림책출판',
#  '#육아스타그램',
#  '#맘스타그램',
#  '#육아',
#  '#도치맘',
#  '대디북',
#  '어버이날선물추천',
#  '부모님선물추천',
#  '어버이날',
#  '가정의달',
#  '마미북',
#  '배불러그램',
#  '맛스타그램',
#  '삼우실',
#  '명민호',
#  '척하면_착_지이크파렌하이트',
#  '직장생활꿀팁키트',
#  '프로직장생활러',
#  '직장인',
#  '직장인스타그램',
#  '지이크파렌하이트',
#  '트리플',
#  '트리플과여행중',
#  'triple',
#  '여행감성',
#  'travel',
#  '여행에미치다',
#  '여행그램',
#  '퀘이커',
#  '오트밀',
#  '핫시리얼',
#  '아침식사',
#  '오트밀레시피',
#  '오트밀먹는법',
#  '동상이몽',
#  '소이현인교진',
#  '소이현안교진',
#  '모닝와이드',
#  '수분쿠션',
#  '3중기능성화장품',
#  'PA++++',
#  '대디북마미북세트',
#  '미드',
#  '정주행',
#  '미드추천',
#  '브라운시리즈5',
#  '브라운AI면도기',
#  '면도시간절약',
#  '독일면도기',
#  '면도기추천',
#  '피부보호면도기',
#  '면도방법',
#  '전기면도기입문템',
#  '면도보다중요한면도기',
#  '아침준비꿀템',
#  '쉬운면도',
#  '브라운시리즈3',
#  '스냅스',
#  '포토북',
#  '스냅스포토북',
#  '어버이날선물',
#  '어버이날포토북',
#  '부모님포토북',
#  '안녕하신가영',
#  '감성스타그램',
#  '감성',
#  '한강',
#  '한강에서',
#  '노래추천',
#  '음스타그램',
#  '앱솔루트엘릭스',
#  'absolutelyx',
#  '24시간이편한',
#  '와이어리스브라',
#  '노와이어브라',
#  '인생브라',
#  '속옷추천',
#  '브라추천',
#  '여성속옷추천',
#  '디어달리아 ',
#  'DearDahlia ',
#  '대리석립스틱 ',
#  'VeganFriendly ',
#  'CleanBeauty ',
#  'CrueltyFree',
#  '이사모아 ',
#  '이사 ',
#  '원룸이사 ',
#  '용달 ',
#  '이사어플 ',
#  '자취생 ',
#  '이사비용계산기 ',
#  '이사비용 ',
#  '이사준비 ',
#  '이사가자',
#  '재즈라운지',
#  '재즈바',
#  '성수동',
#  '포지티브제로라운지',
#  'positivezero',
#  '와인바',
#  '소이현',
#  '인교진',
#  '댕댕이여러분',
#  '냥냥이여러분',
#  '댕댕이보험',
#  '냥냥이보험',
#  '교보라이프플래닛',
#  '댕댕이보험이벤트',
#  '냥냥이보험이벤트',
#  '크론',
#  '운동화',
#  '스니커즈',
#  '아모레퍼시픽',
#  '가장눈부신지금',
#  '유스레볼루션',
#  '유스레볼루션래디언스컨센트레이터',
#  '정화안티에이징',
#  ' 재즈바',
#  ' 성수동',
#  ' 포지티브제로라운지',
#  ' positivezero',
#  '(제품명)',
#  'VLAB',
#  '브이랩',
#  '발세정제',
#  '강아지발세정제',
#  '워터리스풋클린저',
#  '펫닥',
#  '설린크림',
#  '설화수설린크림',
#  '설린',
#  '송혜교매화크림',
#  '피부피로',
#  '생기탄력',
#  '탄력크림',
#  '곤지암',
#  '강아지산책',
#  '#24시간이편한',
#  '#유니클로',
#  '#와이어리스브라',
#  '#노와이어브라',
#  '#인생브라',
#  '치즈',
#  '달총',
#  '새벽',
#  '새벽감성',
#  '거짓말처럼',
#  '디어달리아',
#  'DearDahlia',
#  'VeganFriendly',
#  'CleanBeauty',
#  '츄파FUN팩토리',
#  '스타필드',
#  'FOREVERFUN',
#  '여에스더',
#  '여에스더유산균',
#  '에스더몰',
#  '에스더포뮬러',
#  '프로바이오틱스',
#  '장건강',
#  '쾌변',
#  '영양제',
#  '건강식품',
#  '멈',
#  'Dok2샴페인',
#  'DareWinCelebrate',
#  '멈추지않는도전',
#  'MUMM',
#  '샴페인',
#  '사브라지',
#  '호텔나우',
#  '호캉스',
#  '프라이빗딜',
#  '우아솜메',
#  'ouahsommet',
#  '우아솜메(제품명)',
#  '여행갈때뭐입지',
#  '트래블웨어',
#  '굿초이스',
#  '여행룩',
#  '여행필수품',
#  '그린핑거',
#  '촉촉한자연보습',
#  '아기로션',
#  '아기샴푸',
#  '베이비로션',
#  '베이비샴푸',
#  '스페인올리브',
#  '피부기초체력',
#  '수분지속력',
#  '협찬이지만솔직후기',
#  '제임슨',
#  ' 위스키',
#  '아이리시위스키',
#  '세인트패트릭데이',
#  '한정판',
#  '맨솔',
#  'mansole',
#  '수제화',
#  '아티스트콜라보',
#  '김병조',
#  '펜드로잉',
#  'PWAC',
#  '롯데월드타워',
#  ' 달총',
#  ' 감성스타그램',
#  ' 감성',
#  ' 새벽',
#  ' 새벽감성',
#  ' 노래추천',
#  ' 음스타그램',
#  ' 거짓말처럼',
#  'GetCloser',
#  'DUO',
#  'DUO콘돔',
#  '게임스타그램',
#  '닌텐도스위치',
#  '애플워치',
#  '스콘챔',
#  '닦아쓰는토너',
#  '유산균에센스',
#  '보라병에센스',
#  '미백주름개선화장품',
#  '응답하라오천만',
#  '응오',
#  '땡큐맘2018',
#  '2018평창',
#  '피앤지',
#  'sponsoredbypg',
#  '더블하트',
#  '모태보습',
#  '더블하트모태보습',
#  '태지보습',
#  '모태보습스킨케어',
#  '신생아워시',
#  '신생아오일',
#  '아기피부관리',
#  '아기피부',
#  '아기보습',
#  '아기스타그램',
#  '더블하트모태보습스킨케어',
#  '#디어달리아',
#  '시코르신세계강남점',
#  '마카롱팔레트',
#  'mentos',
#  '멘토스초코',
#  'mentoschoco',
#  '장미맨숀',
#  '멘토스초코샘플링',
#  '커피는멘토스와',
#  '@airasia_korean',
#  '초코',
#  '요리하다',
#  '만다복',
#  '백년짜장',
#  '하얀백년짜장',
#  '주말짜장면',
#  '힐링디너',
#  'yorihada',
#  'lottemart',
#  '차이나타운',
#  '짜장면',
#  '초간편요리',
#  '효리네민박',
#  '효리네민박2',
#  '효리네민박토퍼',
#  '효리네토퍼',
#  '이효리토퍼',
#  '토퍼매트리스',
#  '슬로우',
#  'slou',
#  '매트리스',
#  '타퍼',
#  '토퍼',
#  '시디즈아띠',
#  '디즈니아띠',
#  '인스타베이비',
#  '아들스타그램',
#  '딸스타그램',
#  '유아의자',
#  '정대세의자',
#  '대세의자',
#  '@airasia_kroean',
#  '작가의탄생',
#  '책만들기',
#  '아마존',
#  '그림책',
#  '어린이작가',
#  '아마존출판',
#  '작가',
#  '평창동계올림픽',
#  '라이트업아이스링크',
#  '동대문아이스링크',
#  'DDP아이스링크',
#  '라이트업유어에너지',
#  '현대자동차',
#  '현대차아이스링크',
#  '인증샷이벤트',
#  '마케팅',
#  '책읽기',
#  '직장인추천도서',
#  '초보마케터',
#  '프리미엄콘돔',
#  '발렌타인데이',
#  '자연방목',
#  '아기치즈',
#  '남양아기치즈',
#  '드빈치',
#  '치즈요리',
#  '어린이치즈',
#  '에이치로즈',
#  '다니엘헤니',
#  '남성화장품',
#  '남자화장품',
#  '쉐이빙폼',
#  '함께했S',
#  'FILA',
#  '휠라',
#  'filatogether',
#  '자정미백에센스',
#  '동안에센스',
#  '해말간피부',
#  '미백에센스',
#  '미백',
#  '미백관리',
#  '에센스추천',
#  '미백화장품',
#  '화이트닝에센스',
#  '#응답하라오천만',
#  ' #응오',
#  ' #피앤지',
#  ' #2018평창',
#  ' #sponsoredbyPG',
#  '#응오',
#  '#피앤지',
#  '#2018평창',
#  'sponsoredbyPG',
#  '#sponsoredbyPG',
#  '셔츠',
#  'EFC셔츠',
#  '유니클로셔츠',
#  '에브리데이셔츠',
#  '추후공개',
#  '쉬운캠페인',
#  '어서어서지원',
#  '병맛',
#  ' 바나나툰 ',
#  '레진코믹스 ',
#  '웹툰 ',
#  '추천 ',
#  '일상 ',
#  '일상스타그램 ',
#  'daily',
#  '이지오픈탭',
#  '지퍼백',
#  '생활꿀팁',
#  '지퍼팩',
#  '명절음식',
#  '냉장고파먹기',
#  '소분',
#  '지퍼락상상하는대로사용하세요',
#  '음식물쓰레기버리는법',
#  '디어달리아쇼룸',
#  '듀얼팔레트',
#  '컬렉션세트',
#  'DualPalette',
#  'CollectionSet',
#  '다이나핏',
#  'Dynafit',
#  'BackToSchool',
#  '신학기',
#  '신학기백팩',
#  '백팩추천',
#  '가방추천',
#  'Backpack',
#  '신학기신발',
#  '운동화추천',
#  '신발추천',
#  '더블하트섬유세제',
#  '더블하트섬유유연제',
#  '더블하트세제',
#  '세제',
#  '안심빨래',
#  '안심세제',
#  '아기세제',
#  '유아세제',
#  '아기옷세탁',
#  '야노시호',
#  '야노시호진공샴푸',
#  '진공샴푸',
#  '샴푸추천',
#  '야노시호샴푸',
#  '겨울철샴푸',
#  '무실리콘샴푸',
#  '탈모방지',
#  '트루엘',
#  '핑크세럼',
#  '히비스커스',
#  '히비스커스세럼',
#  '화장품스타그램',
#  '코스메틱',
#  '브랜드체험',
#  '히스토랩',
#  '해시태그',
#  '미디언스',
#  '비트코인',
#  '이동욱',
#  '코인원',
#  'LiveLoud',
#  'LED벨로스터',
#  '벨로스터',
#  'LED자동차',
#  'LED퍼포먼스',
#  'LED위장막',
#  '신형벨로스터',
#  '블링블링카',
#  '벨로스터터보',
#  ' 응오',
#  ' 피앤지',
#  ' 2018평창',
#  ' sponsoredbyPG',
#  'd',
#  '유플러스우리집AI',
#  '우리집AI',
#  'AI스피커',
#  '클로바프렌즈플러스',
#  'clovafriendsplus',
#  'LG유플러스',
#  '홈IoT',
#  '유플러스tv',
#  '오늘은풀러스로가자',
#  '풀러스',
#  'poolus',
#  '카풀',
#  '카풀앱',
#  '아임미미',
#  '틱톡틴트',
#  '틴트추천',
#  '블랙미러',
#  '알베르토자코메티',
#  '조각가',
#  '예술의전당',
#  '한국특별전',
#  '더블유드레스룸',
#  'wdressroom',
#  '롤온향수',
#  '귀요미',
#  '세트',
#  '향스타그램',
#  '브라이트',
#  '윌스미스',
#  '카카오T',
#  '카카오T드라이버',
#  '대리운전',
#  '택시',
#  '카카오택시',
#  '신현희와김루트',
#  '대박콜라보',
#  '윤딴딴',
#  '실화냐',
#  '추후공지예정',
#  '플레시아',
#  '플레시아물감키트',
#  '잇몸케어',
#  '내추럴치약',
#  '치약스타그램',
#  '건강',
#  '치약키트',
#  '레진코믹스',
#  '웹툰',
#  '바나나툰',
#  '좋아요',
#  'OO역',
#  '지하철',
#  '셀카',
#  '일상스타그램',
#  '그래서건강',
#  '라이브방송',
#  '에이비자르',
#  'V리프팅팩',
#  '러플리코스메틱',
#  '연예인팩',
#  '#조선미녀',
#  '#꽃담',
#  '#필링젤',
#  '#1분 필링젤',
#  '#1분',
#  '#소녀 필링젤',
#  '#소녀',
#  '어묵티',
#  '티백',
#  '죠스어묵티',
#  '더블하트젖병',
#  '신생아젖병',
#  'SofTouch모유실감',
#  '토이젖병',
#  '국민젖병',
#  '모유실감젖병',
#  '젖병추천',
#  '아기젖병',
#  '사탕',
#  '초콜릿',
#  '카라멜',
#  '@SKII',
#  'YourStatementYourbottle',
#  'SKII',
#  'SK2',
#  '피테라리미티드에디션',
#  '나의이야기나의피테라',
#  'sk2제공',
#  '백화수복',
#  '백화수복원컵',
#  '전통주',
#  '사케',
#  '캠핑',
#  '골프',
#  '낚시',
#  '정종',
#  '프릴',
#  'Pril',
#  '프릴시크릿오브베이킹소다',
#  '프릴주방세제',
#  '요리',
#  '쿡스타그램',
#  '주방세제',
#  '세븐일레븐',
#  '레진코믹스기프트카드',
#  '#타라',
#  '#홍차',
#  '#홍차추천',
#  '#프리미엄홍차',
#  '#홈카페',
#  '#티마스터',
#  '#차한잔의여유',
#  '#티타임',
#  '#홍차스타그램',
#  '#티스타그램',
#  '#차스타그램',
#  '#협찬이지만솔직후기',
#  '팬틴골든미라클',
#  '극손상헤어케어',
#  '헤어손상순삭',
#  '팬틴골든미라클팝업스토어',
#  '팬틴팝업스토어',
#  '컬트필름클럽',
#  '올드보이하우스',
#  'dddd',
#  '이지덤뷰티',
#  '티안나게빨리낫자',
#  '여드름패치',
#  '여드름패치추천',
#  '이지덤',
#  '포니패치',
#  '##sponsoredbyPG',
#  '#케어스타터',
#  '#욕실토너',
#  '#더마코스메틱',
#  '#닦아쓰는토너',
#  '#퍼스트케어',
#  '#프라우드메리',
#  '#히스토랩',
#  '#프레시코드 #샐러드 #맛있고배부른샐러드 #샐러드맛집 #배달샐러드 #새벽배송 #프코스팟 #프레시코드샐러드 #프코샐러드 #샐러드배송',
#  '엣모스피어드라이브',
#  'atmosphere_drive',
#  '암웨이',
#  '암웨이차량용공기청정기',
#  '암웨이공기청정기',
#  '엣모스피어',
#  '차량용공기청정기',
#  '차량공기청정기',
#  '소형공기청정기',
#  '자동차공기청정기',
#  '추울땐',
#  '불러줘요',
#  '카카오드라이버',
#  '자동결제',
#  '한번에',
#  '문제없어요',
#  '손가락하나로',
#  '기사님안녕하세요',
#  '말도안했는데',
#  '목적지착착',
#  '기묘한이야기',
#  '강아지하네스',
#  '하네스',
#  '강아지목줄',
#  '목줄',
#  '반려동물',
#  '강아지',
#  '밀로티',
#  '처음본순간',
#  '알았죠',
#  '내기사님인거',
#  '편하다',
#  '어디든',
#  '갈수있어요',
#  '편리하다',
#  '이제 ',
#  '현금은',
#  '넣어둬',
#  '어디까지',
#  '갈까요',
#  '기사님',
#  '수고하세요',
#  '소파사운즈',
#  'sofasounds',
#  'sofasoundsseoul',
#  '송스타그램',
#  '노래',
#  '음악',
#  '마리약국',
#  '마리끌레르',
#  '츠바키',
#  '츠바키리페어에센스',
#  '#마리약국',
#  '#마리끌레르',
#  '#셀더마',
#  '#예쁨팩',
#  '#투명팩',
#  '#인스티튜트카리테',
#  '#퓨어시어버터',
#  '일리윤',
#  '일리윤세라마이드아토집중크림',
#  '잇츠스킨',
#  '파워10포뮬라',
#  '결혼준비',
#  '수입드레스샵',
#  '웨딩드레스샵추천',
#  '이노센트웨딩',
#  '드레스화보',
#  '강남구청역',
#  '기묘한이야기2',
#  '#츠바키',
#  ' #TSUBAKI',
#  ' #기다리는시간0초',
#  ' #헤어클리닉',
#  ' #프리미엄리페어마스크',
#  ' #츠바키리페어에센스',
#  ' #극손상모케어',
#  ' #집에서하는헤어클리닉',
#  ' #송지효',
#  ' #예쁨팩',
#  ' #29gram',
#  ' #투명팩',
#  ' #institutkarite',
#  '#100%퓨어시어버터',
#  ' #시어버터',
#  ' #멀티밤',
#  ' #바디밤',
#  ' #저자극',
#  ' #시코르',
#  ' #부츠',
#  ' #겨울바디보습',
#  '#잇츠스킨',
#  '#itsskin',
#  '#파워10포뮬라',
#  '#색다른파워10',
#  '#파워10스타그램',
#  '#일리있는체인지',
#  ' #일리윤',
#  ' #자습크림',
#  ' #민감성피부',
#  ' #가을필수템',
#  ' #다른보습',
#  ' #자습',
#  ' #보습크림추천',
#  ' #일리윤세라마이드아토집중크림',
#  ' sofarsounds',
#  ' sofarsoundsseoul',
#  ' 송스타그램',
#  ' 노래',
#  ' 음악',
#  '브라이덜패션이야기',
#  '브라이덜패션',
#  '웨딩',
#  '결혼',
#  '스칼라티움',
#  '이은실',
#  '헤리티크뉴욕',
#  'NY브라이덜',
#  '필리파',
#  '저스트필리파',
#  '#@SKII',
#  ' #YourStatementYourbottle',
#  ' #SKII',
#  ' #SK2',
#  ' #피테라리미티드에디션 ',
#  ' #나의이야기나의피테라',
#  ' #sk2제공',
#  '옥수수',
#  'oksusu',
#  'original',
#  '멜로홀릭',
#  '동방신기',
#  '유노윤호',
#  '정윤호',
#  '경수진',
#  '웹드라마',
#  '포니패치 ',
#  ' #부드러운',
#  ' #홍차',
#  ' #홍차타라',
#  ' #홍차추천',
#  ' #여유',
#  ' #티타임',
#  ' #홍차스타그램',
#  ' #티스타그램',
#  ' #차스타그램',
#  '복수노트',
#  '김향기',
#  'ASTRO',
#  '차은우',
#  '박솔로몬',
#  '김환희',
#  '올드보이',
#  '#잃어버린마음찾기',
#  ' #마음봇',
#  ' #현대해상',
#  ' #잃어버린마음을찾아주세요',
#  '#YourStatementYourbottle',
#  '#SKII',
#  '#SK2',
#  '#피테라리미티드에디션',
#  '#나의이야기나의피테라',
#  '풋샴푸',
#  '발샴푸',
#  '워터리스풋클렌저',
#  '펫닥 ',
#  '펫스타그램',
#  "'@SKII",
#  '순수코스메틱',
#  '순수메이크업',
#  '수경원장',
#  '민낯크림',
#  '내피부가좋아하는',
#  '톤업크림추천',
#  '수분폭탄',
#  '민낯의자신감',
#  '하나카드',
#  '레진코믹스카드',
#  '출퇴근',
#  '영수증',
#  '슈퍼그레잇',
#  '택시보다싸다',
#  '니베아립케어',
#  '메시지에디션',
#  '립밤',
#  '정주행 ',
#  'ㄴ',
#  '#더블하트',
#  '#모태보습',
#  ' #첫순간그램',
#  ' #더블하트모태보습스킨케어',
#  ' #아기첫보습',
#  ' #모태보습이벤트',
#  ' #베이비워시',
#  ' #베이비오일',
#  ' #신생아오일',
#  ' #아기바디워시',
#  '#더블하트스킨케어',
#  ' #아기마사지',
#  ' #협찬이지만솔직후기',
#  '희생부활자',
#  '김래원',
#  '김해숙',
#  '성동일',
#  '전혜진',
#  '희생부활자시사회',
#  '희생부활자꿀잼',
#  '희생부활자대박',
#  '윤건과함께',
#  '우리둘만아는',
#  '뮤비를만들자',
#  '윤건',
#  '윤건새음원',
#  '감성아이콘',
#  '감성치트키',
#  '뮤직비디오',
#  '뮤비스타그램',
#  '클라우드',
#  '클라우드모먼트',
#  '라퓨타',
#  '클라우드루프탑파티',
#  '열정세션',
#  '열정크루',
#  'togocrew',
#  '열정의에스프레소',
#  '열정키트',
#  '와우산30',
#  '열정',
#  '열정인터뷰',
#  '마이열정크루',
#  '크루',
#  '옴니닷컴',
#  '옴니쇼핑',
#  '나도옴니로산다',
#  '옴니CF',
#  '옴니TVC',
#  '옴니가좋다',
#  'melon',
#  '멜론스타그램',
#  '스마트i',
#  '날위한선곡',
#  'OO이필요한순간',
#  '소통',
#  '음스타그램 ',
#  '추억팔이',
#  '마니또',
#  '시스맨스',
#  'OO가필요한순간',
#  '웹툰추천',
#  ' 인생웹툰',
#  '우리사이느은',
#  '드레스카페',
#  ' 웨딩드레스',
#  ' 결혼준비',
#  ' 더블유스페이스',
#  '데이트코스',
#  '티오피에세이',
#  '티오피X쪽프레스',
#  '티오피X쪽프레스에세이',
#  'MILD',
#  'BOLD',
#  'TRUE',
#  'Sulwhasoo',
#  '설화수CSR',
#  'BeautyFromYourCulture',
#  '설화문화전',
#  '설화수전시회',
#  '설화수설화문화전',
#  '차량용방향제',
#  '핸드크림',
#  '하이네켄다크',
#  '다크라거',
#  '다크포스충전중',
#  'sofarsounds',
#  'sofarsoundsseoul',
#  '사서고생',
#  '박준형',
#  '소진',
#  '소유',
#  '정기고',
#  '뉴이스트',
#  '예능',
#  '#설화수',
#  ' #Sulwhasoo',
#  ' #설화수CSR',
#  ' #BeautyFromYourCulture',
#  ' #설화문화전',
#  ' #설화수전시회',
#  ' #설화수설화문화전',
#  '쓰리액티브디펜스선크림',
#  'carenology',
#  '에어자차',
#  '선크림',
#  '공기같은사용감',
#  '자외선차단제',
#  '피부과화장품',
#  '먼슬리코스메틱',
#  '나만의화장품',
#  'monthlycosmetics',
#  '맞춤화장품',
#  '맞춤화장품_먼슬리코스메틱',
#  '유기농화장퓸_먼슬리코스메틱',
#  '#쫀쫀크림',
#  '#파워업케어',
#  '스타일쉐어',
#  '2017마켓페스트',
#  '나만의스타일을찾아떠나는여행',
#  '에스팀',
#  '타임세일',
#  '플리마켓',
#  '축제',
#  '마켓페스트',
#  '스쉐마켓페스트',
#  'Heiniken',
#  '부산국제광고제',
#  '벡스코',
#  'OneBottleAwayFrom',
#  '피테라한병캠페인',
#  'sk2',
#  'skii',
#  '막걸리카노',
#  '커피막걸리',
#  '국순당',
#  'CU편의점',
#  '존맛탱',
#  '코나',
#  '코나드라이빙스쿨',
#  '고양스타필드',
#  '메가박스',
#  '메가박스고양',
#  '주말데이트',
#  '나들이',
#  '기네스',
#  '흑맥주',
#  '편의점맥주',
#  '배정남',
#  '김영하',
#  '질소거품',
#  '서징',
#  '기네스맥주',
#  '배정남맥주',
#  'madeofmore',
#  '수입맥주',
#  '사조사료',
#  '오러브잇',
#  '오러브잇사료',
#  'oloveat',
#  '김민석',
#  '남자청바지',
#  '강동원청바지',
#  '진이노베이션센터',
#  'LifeWear',
#  '#청바지',
#  '#데님',
#  '#여자청바지',
#  '#유니클로진',
#  '#UNIQLO',
#  '마일드에스프레소라떼',
#  '볼드에스프레소라떼',
#  '트루에스프레소블랙',
#  '티오피컵커피',
#  '테이스팅노트',
#  'TOPCUP',
#  '디펜더스',
#  '목격자를찾습니다',
#  'kona',
#  'konadrivingschool',
#  '#OneBottleAwayFrom ',
#  '#피테라한병캠페인',
#  '#sk2',
#  '#skii',
#  '데스페라도스',
#  'Desperados',
#  '데낄라맥주',
#  '그래도인생은파티니까',
#  '인생맥주',
#  '파티',
#  '파티맥주',
#  '햇반컵반',
#  '박보검',
#  '가정식',
#  '가정식맛집',
#  '맛집탐방',
#  '1인식당',
#  '올리브마켓',
#  'IFC몰',
#  '여의도맛집',
#  '스키니진',
#  '울트라스트레치진',
#  '울트라스트레치스키니피트진',
#  '데님',
#  '시가렛진',
#  '하이라이즈시가렛진',
#  '탈모',
#  '탈모예방',
#  '두피열',
#  '모발강화',
#  '모근강화',
#  '건강음료',
#  '블랙레시피',
#  '그다이',
#  '굿즈',
#  '쿠폰북',
#  '티셔츠',
#  '선물스타그램',
#  '하하 ',
#  ' 커먼그라운드',
#  '대만곰돌이방향제',
#  '곰돌이방향제',
#  '대만쇼핑',
#  '대만쇼핑리스트',
#  '대만쇼핑필수품',
#  '대만자유여행',
#  '아이엠퓨다',
#  '디네앙블랑',
#  '디네앙블랑부산',
#  'moov',
#  'dinerenblanc',
#  'party',
#  '롯데카드',
#  '로카랩',
#  '#레진코믹스',
#  ' #웹툰추천',
#  ' #그다이',
#  ' #좋아요',
#  ' #지하철',
#  ' 셀카',
#  '방문한역 이름',
#  '완벽한순간',
#  '완벽한쿠션',
#  '완벽한OO',
#  '커버력좋은쿠션',
#  '퍼펙팅쿠션',
#  ' sofarsoundsseoul ',
#  '클럽케이서울',
#  '라온버스',
#  '백미당',
#  '백미당공방',
#  '백가지맛있는경험',
#  '미정 추후공지',
#  '#강황이날강화',
#  ' #건강스타그램',
#  ' #운동스타그램',
#  ' #운스타그램',
#  ' #식단',
#  ' #건강음료',
#  ' #면역력강화',
#  ' #숙취해소',
#  ' #숙취해소음료',
#  ' #피부관리',
#  ' #몸매관리',
#  ' #아이엠퓨다',
#  ' #행복한백수들',
#  ' #강황',
#  'shaka',
#  'suv',
#  '라메르',
#  'Lamer',
#  '나를위한여행동반자',
#  '면세점화장품',
#  '#프레시코드',
#  ' #프코샐러드',
#  ' #배송샐러드',
#  ' #맛있는샐러드',
#  ' #배부른샐러드',
#  '#맛있는다이어트',
#  ' #배부른다이어트',
#  ' #가성비갑',
#  ' #고퀄샐러드',
#  ' #맛스타그램',
#  ' 더블하트섬유세제',
#  '더블하트세탁세제',
#  '안심빨래를부탁해',
#  '내나이가어때서',
#  'INeverExpire',
#  '아기섬유유연제',
#  '신생아세제',
#  '픽트',
#  '다크서클',
#  '꼭꼭숨어라',
#  '올마이티컬러코렉터',
#  '컨실러',
#  '#여름',
#  ' #공포',
#  ' #스릴러',
#  ' #웹툰',
#  ' #추천',
#  ' #일상',
#  ' #일상스타그램',
#  ' #daily',
#  '칭따오',
#  '칭따오맥주',
#  '맥주추천',
#  '정상훈',
#  '정상훈맥주',
#  'funbeer',
#  '펀비어',
#  '술자리의재미를살려라',
#  '맥가이비어',
#  '오티',
#  '샴푸',
#  '컨디셔너',
#  '향이넘나좋은것',
#  '넷플릭스 ',
#  '아기물티슈',
#  '안전한물티슈',
#  '물티슈',
#  '아유레디',
#  '물티슈추천',
#  '잘풀리는집',
#  '아유레디아기물티슈',
#  '나이에유통기한은없다',
#  'changedestiny',
#  ' ineverexpire',
#  'skii ',
#  ' SK2',
#  '리얼씨리얼',
#  '리얼씨리얼푸드바',
#  '푸드바',
#  '다먹고살자고하는거야',
#  '건강푸드바',
#  '바디워시',
#  '바디로션',
#  'moimoii',
#  '비치웨어',
#  '모이모이',
#  '니트웨어',
#  '여름니트',
#  '스타일링',
#  '제품이름해시태그',
#  '옥자',
#  '봉준호',
#  '에어맥스',
#  '신상',
#  '정품',
#  '핫템',
#  '읽으신작품명',
#  'desperados',
#  '나를위한선물',
#  '달다구리',
#  '남치니마스크팩',
#  '여행팩',
#  '남치니팩',
#  '희노애락팩',
#  '여신강림',
#  '국보급미모',
#  '아름다움',
#  '섹시도발',
#  '감정표현팩',
#  'masksheetpack',
#  'namchinipack',
#  '야구장팩',
#  '그제품의사연',
#  '핑거패드',
#  '커먼랩스',
#  'commonlabs',
#  'fingerpad',
#  '젤마스크팩',
#  '팩추천',
#  '리얼젤마스크',
#  'Kbeauty',
#  '꿀타민',
#  '#옥자야',
#  ' #옥자',
#  ' #넷플릭스',
#  ' #넷플릭스오리지널',
#  ' #영화',
#  ' #봉준호',
#  '유아수딩젤',
#  '땀띠수딩젤',
#  '베이비세라마이드',
#  '수딩젤',
#  '태열수딩젤',
#  '가족여행추천',
#  '아이선크림',
#  '화해1위선크림',
#  '야외놀이선크림',
#  '나를위한보상',
#  ' SKII',
#  ' @SKII',
#  ' INeverExpire',
#  '마이비데',
#  '마이비데키즈',
#  '배변훈련',
#  '응가',
#  '육아그룹',
#  '동화책',
#  '세젤귀',
#  '크리넥스',
#  '베이비선쿠션',
#  '유아선크림',
#  '촉촉선팩트',
#  '신생아수딩젤',
#  '아기수딩젤',
#  '아기선크림',
#  '순한선크림',
#  '워셔블선크림',
#  '하우스오브카드',
#  '하오카',
#  '정치',
#  '대통령',
#  '#해외직구',
#  ' #지니집',
#  ' #스페인직구',
#  ' #스페인자라',
#  ' #자라',
#  ' #자라직구',
#  ' #ZARA',
#  ' #빔바이롤라',
#  ' #빔바이롤라직구',
#  ' #BIMBAYLOLA',
#  ' #스페인배송비',
#  ' #스페인배대지',
#  ' #지니집스페인',
#  '코팩추천',
#  '피지제거',
#  '바르는코팩',
#  '3단코팩',
#  '프리미엄코팩',
#  '아비셀',
#  'avicell',
#  '손세정제',
#  '세니타이저',
#  '생활필수템',
#  'instalike',
#  '쁘띠첼',
#  '우리회사곳간',
#  '스윗푸딩',
#  '솔직후기',
#  '푸딩',
#  '@cjpetitzel',
#  '#응답하라',
#  ' #우리가족',
#  ' #가족스타그램',
#  ' #에너지한스푼',
#  ' #IamYourEnergy',
#  '#Desperados',
#  ' #데낄라맥주',
#  ' #그래도인생은파티니까',
#  ' #인생맥주',
#  ' #파티',
#  ' #파티맥주',
#  '#에센스',
#  ' #에센스추천',
#  ' #화장품',
#  ' #화장품추천',
#  ' #뷰티스타그램',
#  ' #뷰스타그램',
#  ' #화장품스타그램',
#  ' #뷰티',
#  ' #뷰티템',
#  ' #스킨케어',
#  ' #꿀피부',
#  ' #인생에센스',
#  ' #동인비',
#  ' #자생원액에센스',
#  ' #피부뿌리부터힘있게',
#  ' #피부Reset',
#  ' #동인비4주체험단',
#  ' #정관장',
#  ' #한가인화장품',
#  ' #한가인에센스',
#  ' #홍삼화장품',
#  ' #홍삼에센스',
#  ' #해외쇼핑몰',
#  ' #해외쇼핑',
#  ' #롯지',
#  ' #레고',
#  ' #힐리스',
#  ' #벤시몽',
#  ' #미네통카',
#  ' #뷰티블랜더',
#  ' #닥터브라운',
#  ' #거버나이프',
#  '지니샵',
#  '든든',
#  '고소해',
#  '나만의레시피',
#  '요리사',
#  '음식스타그램',
#  'LSNmall',
#  'AIRING',
#  '오늘뭐입지',
#  '패스타그램',
#  '#메가박스',
#  '#송도점',
#  '#오픈',
#  ' #모태보습',
#  ' #더블하트모태보습',
#  ' #더블하트베이비로션',
#  ' #아기로션',
#  ' #베이비로션',
#  ' #신생아로션',
#  ' #더블하트섬유세제',
#  ' #더블하트섬유유연제',
#  ' #더블하트세제',
#  ' #더블하트세탁세제',
#  ' #더블하트유아섬유유연제',
#  ' #아기섬유유연제',
#  ' #아기세제',
#  ' #유아세제',
#  ' #신생아세제',
#  ' #아기용품',
#  ' #아기옷세탁',
#  ' #육아스타그램',
#  ' #젖병세정제',
#  ' #더블하트젖병세정제',
#  ' #젖병관리',
#  ' #젖병세정',
#  ' #신생아필수품',
#  '설현팬사인회',
#  '자연원',
#  '오클렌즈',
#  '클렌즈',
#  '클렌즈쥬스',
#  'clease',
#  '건강식',
#  '데일리',
#  '클렌즈주스',
#  '페스티벌',
#  '월디페',
#  '호치킨',
#  '호치킨OO점',
#  'OO동맛집',
#  '호치킨신메뉴',
#  '불끈이',
#  '아만다',
#  '합격',
#  '아만다점수',
#  '아만다합격',
#  '#히오스 ',
#  '#시공조아',
#  '#히어로즈',
#  '#영등포CGV',
#  '#월드타워롯데',
#  '#쇼미더보트',
#  ' #투표인증',
#  ' #메가박스',
#  ' #꿀팁',
#  '쇼미더보트',
#  '투표인증',
#  '매그넘 ',
#  '나를위해준비했어',
#  '달콤한선물',
#  '달콤한보상',
#  '봄꽃쉼표',
#  '에너지한스푼',
#  'IamyourEnergy',
#  '봄',
#  '꽃놀이',
#  '힐링',
#  '대통령 ',
#  '선거',
#  '헤어레시피',
#  '꿀살샴',
#  '꿀살구샴푸',
#  'hairrecipe',
#  '오직티몬에서만',
#  '#헤어레시피',
#  '#꿀살샴',
#  '#꿀살구샴푸',
#  '#hairrecipe',
#  '#오직티몬에서만',
#  '켈로그에너지바',
#  '에너지바',
#  '간식',
#  '예님',
#  '볼륨메이크업',
#  'SB크림',
#  '스마일뷰티',
#  '데일리메이크업',
#  '도화살메이크업',
#  '예님볼륨메이크업',
#  '비비크림추천',
#  '물광비비',
#  '윤광메이크럽',
#  '논투어링',
#  '스카트',
#  '스카트행주',
#  '행주',
#  '주방관리의노하우',
#  '블루타올',
#  '요즘행주',
#  '요즘행주스카트',
#  '빨아쓰는타올',
#  '위생적인행주스카트',
#  'scott',
#  '주방필수품',
#  '수퍼바이오틱스',
#  '주부스타그램',
#  '몸스타그램',
#  '요즘대세',
#  '키즈유산균',
#  '어린이유산균',
#  '아이유산균',
#  '더블하트유아섬유유연제',
#  '아기용품',
#  '젖병세정제',
#  '더블하트젖병세정제',
#  '젖병관리',
#  '젖병세정',
#  '신생아필수품',
#  '라네즈',
#  '프레시카밍',
#  '수부지',
#  '믿고쓰는라네즈',
#  '프레시카밍토너',
#  '프레시카밍모닝마스크',
#  '구매장소',
#  '더블하트베이비로션',
#  '신생아로션',
#  '아기마사지',
#  '메가쿠폰',
#  '현대카드ZERO',
#  '현대카드',
#  '쓸때마다할인',
#  '할인카드',
#  '할인카드추천',
#  '첵스초코컬러링',
#  '컬러링',
#  '색칠공부',
#  '치쌈',
#  '화끈이',
#  '존맛',
#  '치느님',
#  '더인소울',
#  '램프디퓨저',
#  '젤디퓨저',
#  '신혼선물',
#  '그제사',
#  '컷팩토리',
#  '향기',
#  '무드등',
#  '소자본창업',
#  'SNS창업',
#  '종합영양제',
#  '멀티비타민',
#  '오메가',
#  '트리플러스',
#  '세노비스',
#  '3++++',
#  '4월한정판',
#  '피로회복',
#  '러브컬쳐',
#  '러브컬처',
#  'loveculture',
#  '지니집',
#  '헐리우드스타일',
#  '헐리우드패션',
#  '파티룩',
#  '시스루',
#  '시스루룩',
#  '오프숄더',
#  '원피스',
#  '데이트룩',
#  '여성의류쇼핑몰',
#  '아니카톰슨',
#  '데일리백',
#  '여성클러치',
#  '클러치백',
#  '가죽클러치',
#  '미니백',
#  '그린핑거선',
#  '그린핑거선크림',
#  '아이편해',
#  '맘이편해',
#  '어느새봄',
#  'IamYourEnergy',
#  '#여성클러치',
#  '민병철유폰',
#  '유폰',
#  '영어회화',
#  '영어공부',
#  '전화영어',
#  '공스타그램',
#  '자기계발',
#  '공부인증',
#  '비즈니스전화영어',
#  '비즈니스영어회화',
#  '일상영어',
#  '직딩',
#  '#엘지유플러스프로야구앱',
#  '마블',
#  '아이언피스트',
#  '크리미오일',
#  '아기오일',
#  'MyNB',
#  '마이앤비',
#  '친구초대랭킹이벤트',
#  '걷기만해도',
#  '포인트적립',
#  '#꿀팁',
#  '#꿀정보',
#  '4교시영화수업',
#  '17자친구이벤트',
#  'Absolutmini',
#  '앱솔루트미니',
#  'Absolutnights',
#  '앱솔루트나이츠',
#  'Miniglass',
#  '미니글라스',
#  '애덜린',
#  '더골든에이지',
#  '프리미엄마스크팩',
#  '팩',
#  '연예인마스크팩',
#  '물광피부',
#  '해외직구',
#  '매직카펫',
#  '해외쇼핑',
#  '미국직구',
#  '독일직구',
#  '일본직구',
#  '스페인직구',
#  '중국직구',
#  '영국직구',
#  '폴로',
#  '폴로랄프로렌',
#  '갭',
#  '망고',
#  '포트메리온',
#  '컨트리타이어',
#  '오시코시',
#  '카터스',
#  '6pm',
#  '이베이',
#  '자라',
#  '타오바오',
#  '라쿠텐',
#  '올드네이비',
#  '바나나리퍼블릭',
#  '애슬레타',
#  '위스키',
#  '아이리쉬위스키',
#  '과일식초',
#  '파인애플초',
#  '깔라만시',
#  '복분자',
#  '딸기',
#  '통째로갈아만든',
#  '해오주스',
#  '야채주스',
#  '레진X할리스',
#  '할리스커피',
#  '레진코믹스의_선물',
#  '만화',
#  '커피',
#  'coffee',
#  '커피스타그램',
#  '무코타',
#  '무코타정품',
#  '무코타헤어오일',
#  '무코타홈케어',
#  '헤어클리닉',
#  '홈클리닉',
#  '헤어케어',
#  '손상모',
#  '건성모',
#  '모발관리',
#  '헤어오일',
#  '헤어오일추천',
#  '오리지널무코타',
#  '정품무코타',
#  'kint',
#  '대박사은품',
#  '14k목걸이',
#  '14k주얼리',
#  '주얼리',
#  '커플',
#  '홈파티',
#  'cleanse',
#  '손씻기',
#  '아이',
#  '핸드워시',
#  '버블핸드워시',
#  '케어',
#  '어린이',
#  '키즈',
#  '아이스타그램',
#  '애스타그램',
#  '수지립스틱',
#  '더페이스샵',
#  '모이스처터치립스틱',
#  '시티브라운',
#  '파도가지나간자리',
#  '마이클패스벤더',
#  '알리시아비칸데르',
#  '노트북에이이은내인생멜로작',
#  '디오리지널',
#  '호로요이',
#  '화이트사워',
#  '피치',
#  '그레이프',
#  'tipsy',
#  '한잔',
#  '과일주',
#  '탄산주',
#  'iamyourenergy',
#  '피테라에센스',
#  '피테라꿀팁',
#  'JCFC',
#  '라이브클럽데이',
#  'LIVECLUBDAY',
#  '쟈뎅',
#  '쟈뎅콜드브루',
#  '그랑브루',
#  '쟈뎅그랑브루',
#  '진한맛',
#  '워터드립커피',
#  '초고압살균커피',
#  '리얼콜드브루',
#  '웰츠',
#  '웰츠사료',
#  '펫푸드',
#  '멍스타그램',
#  '사료추천',
#  '이리온수의사추천사료',
#  'SNOW',
#  '스노우메세지',
#  'SNOW짤영상',
#  '스노우동영상메세지',
#  '짤영상추천',
#  '스노우움짤',
#  '어린이비타민',
#  '어린이영양제',
#  '입학선물',
#  '세노비스키즈삼총사',
#  '세노비스키즈오메가3',
#  '오메가3',
#  '세노비스키즈멀티비타민미네랄',
#  '비타민',
#  '미네랄',
#  '세노비스키즈수퍼바이오틱스',
#  '책육아',
#  '한자육아',
#  '엄마표한자',
#  '브레인나우',
#  '브레인빌딩',
#  '하기스',
#  '하기스오버나이트',
#  '하기스신제품',
#  '밤기저귀',
#  '밤기저귀추천',
#  '통잠기저귀',
#  '꿀잠기저귀',
#  '천연세제',
#  '라쿠아',
#  '여성속옷세제',
#  '액상세제',
#  '속옷세제',
#  '니치세제',
#  '친환경세제',
#  '더블하트베페',
#  '더블하트베이비페어',
#  '베이비페어',
#  '베페',
#  '코엑스',
#  '젖병',
#  '더블하트세정제',
#  '세정제',
#  '더블하트젖꼭지',
#  '출산용품',
#  '유아브랜드추천',
#  '유한킴벌리',
#  'framy',
#  'framyapp',
#  'framyvideo',
#  'loveframy',
#  '리본콜라',
#  '리본코카콜라',
#  'cocacola',
#  '당기면가까워져요',
#  '콘푸로스트',
#  '바나나파워',
#  '무비콜라보',
#  '무료영화쿠폰',
#  'Btv',
#  'ollehtv',
#  '영화감상',
#  '더블하트스킨케어',
#  '더블하트로션',
#  '더블하트오일',
#  '아이로션',
#  '어린이로션',
#  '유아오일',
#  '육아용품',
#  '베이비리피드',
#  '이노시톨',
#  '베이비스킨케어',
#  '무코타트리트먼트',
#  '무코타IM트리트먼트',
#  '무코타정품인증',
#  '프립',
#  '일상을바꿔줄게',
#  '주말에뭐하지',
#  '취미',
#  '여가',
#  '커피리큐르',
#  '강추',
#  '술',
#  '깔루아밀크',
#  '어반스케치',
#  '드로잉',
#  '클라이밍',
#  '실내암벽등반',
#  '암벽등반',
#  '생활속유도',
#  '조준호',
#  '조준현',
#  '쌍둥이유도선수',
#  '메달리스트',
#  '올림머리',
#  '추천음악',
#  '멜로디데이',
#  '바빠보여요',
#  '위로',
#  '공감',
#  '킵쿨마스크팩',
#  '명동올리브영',
#  '랩노쉬후기',
#  'framy ',
#  '티엔',
#  'AC컨트롤레서피',
#  '티엔AC컨트롤레서피',
#  '10대',
#  '10대피부',
#  '여드름고민',
#  '새학기준비',
#  '10대뷰티',
#  '학생',
#  '여학생',
#  '학생피부',
#  'UrbanDriving',
#  'Benz',
#  '벤츠',
#  '이모티콘',
#  '촉촉한',
#  '촉촉한자연보습베이비로션',
#  '아기로션추천',
#  '아기보습제',
#  '더페이스샵쿠션',
#  '디즈니쿠션',
#  '쿠션팩트',
#  '피글렛쿠션',
#  '설리쿠션',
#  '도널드쿠션',
#  '통큰준구씨',
#  '폰케이스',
#  '폰케이스추천',
#  '특이한아이폰케이스',
#  '아이폰6',
#  '아이폰7',
#  '아이폰케이스',
#  '아이폰6케이스',
#  '아이폰7케이스',
#  '맞팔',
#  '그린핑거베이비세라마이드',
#  '세라마이드',
#  '세라마이드크림',
#  '세라마이드로션',
#  '세라마이드워시',
#  '보습력',
#  '유아로션추천',
#  '유아크림추천',
#  '유아워시추천',
#  '뷰티템',
#  '꿀피부',
#  '인생에센스',
#  '동인비4주체험',
#  '티모니',
#  '티모니물티슈',
#  '하기스x티몬',
#  '하기스물티슈',
#  '수딩케어',
#  '아기물티슈추천',
#  '메리츠다이렉트',
#  '몬디',
#  '몬디의직딩라이프2',
#  '이모티콘무료로받아가세요',
#  '플친추가하면자동발송',
#  'OrangeHappyFace',
#  'HappyFace',
#  '오렌지해피페이스',
#  '해피페이스',
#  '행복지수',
#  '행복',
#  '소품',
#  'Activia',
#  '액티비아',
#  '액티비아0%플레인',
#  '14일의변화',
#  '설탕무첨가',
#  '네온',
#  '반짝톡톡',
#  '기분따라색다르게',
#  '행복지수측정',
#  '바유',
#  '바르는유산균',
#  '유산균화장품',
#  '유산균보습',
#  '건돌이',
#  '프로바이오틱스유산균',
#  '프로바이오틱스드롭',
#  'VSL3',
#  'VSL3드롭',
#  '모태모습',
#  '신생아로션추천',
#  '신생아오일추천',
#  '유아로션',
#  'SNS는나의힘',
#  '당첨',
#  '연말',
#  '이쁘진',
#  'lguplus',
#  'P9',
#  '라이카폰',
#  '크리스마스감성',
#  '화웨이P9',
#  '립스틱추천',
#  '색상',
#  '하기스아기물티슈',
#  '하기스프리미어',
#  '신생아물티슈',
#  '메리크리스마스',
#  '크리스마스분위기',
#  '레드판타지',
#  '립덕후',
#  'event',
#  '드라마',
#  '결정장애',
#  '미드나잇',
#  '취향저격',
#  '드라마제목',
#  '영드',
#  '휴식',
#  '영드추천',
#  'ABSOLUTNIGHTS',
#  'ABSOLUT',
#  'FACET',
#  '앱솔루트보드카',
#  '파셋',
#  '심야식당',
#  '일드',
#  '사람냄새',
#  '명작',
#  '심야식당4',
#  'gentlemask',
#  '젠틀마스크',
#  '오일',
#  '수분',
#  'inmybag',
#  '결정장해',
#  '취항저격 ',
#  '#본인이보는드라마제목',
#  '술타민',
#  '이경제',
#  '이경제술타민',
#  '술그램',
#  '음주',
#  '쾌락',
#  '만취',
#  '숙취',
#  '인생미드',
#  '#새티스 #satis #화이트닝크림 #화이트닝크림추천 #새티스퓨어화이트닝크림',
#  '위노나라이더',
#  '밤샘',
#  '다시보기',
#  '길모어걸스',
#  '명작 ',
#  '비피터',
#  '믹스런던코리아',
#  'MIXLDN',
#  '런던드라이진',
#  '칵테일',
#  '천연펄프물티슈',
#  '촉촉한물티슈',
#  '도톰한물티슈',
#  '제이버드',
#  '제이버드프리덤',
#  '블루투스이어폰',
#  '스포츠블루투스이어폰',
#  '스포츠블루투스이오폰',
#  '아몬드온',
#  '요가복',
#  '필라테스복',
#  '예쁜요가복',
#  '요가복추천',
#  '눈바디',
#  '요가',
#  '필라테스',
#  '추천미드제목',
#  '미라클피니시쿠션',
#  '어이쿠쿠션',
#  '배송받으실 제품의 제품명',
#  '셰프의테이블',
#  '온더테이블',
#  '지정생존자',
#  '추천미드',
#  '오늘뭐보지',
#  '키퍼서덜랜드',
#  '주말',
#  '연애의부작용',
#  '영국',
#  '뷰티스타그램 ',
#  '제품명',
#  '미드천국',
#  '이불밖은위험해',
#  '팸퍼스',
#  '기저귀',
#  '기저귀추천',
#  '팬티형기저귀',
#  '팬티형기저귀추천',
#  '갈아입히기쉬운기저귀',
#  '첫번째',
#  '신생아기저귀',
#  '신생아용기저귀추천',
#  'doubleheart',
#  '육아필수품',
#  '유아용품',
#  '더블하트크리미오일',
#  '바디오일',
#  '더크라운',
#  '잡스타그램',
#  '런던',
#  '닥터후',
#  '맷스미스',
#  '아이크림추천',
#  '그린핑거물티슈',
#  '셜록',
#  '베네딕트컴버배치',
#  'patagonia',
#  'NanoPuff',
#  '파타고니아',
#  '나노퍼프',
#  '아웃도어',
#  '자켓',
#  '코디',
#  '등산',
#  'TLXPASS',
#  'TLX',
#  'Today_Lets_Xercise',
#  '티엘엑스',
#  '관리하는여자',
#  '관리하는남자',
#  '운동어플',
#  '다이어트어플',
#  '헬스타그램',
#  '운스타그램',
#  '운동하는남자',
#  '다이어드',
#  '배달의민족',
#  '배민아트',
#  '베르나르프라',
#  '세종대왕',
#  '작품',
#  '전시',
#  '설치미술',
#  '미술',
#  '아트',
#  '디자인',
#  '광화문',
#  '세종문화회관',
#  'art',
#  'artwork',
#  'artist',
#  'designer',
#  'space',
#  '루크케이지',
#  '데어데블',
#  '제시카존스',
#  '제임슨컬트필름클럽',
#  '할로윈',
#  'wolfblass',
#  '울프블라스',
#  '호주와인',
#  '3040와인',
#  '프리미엄와인',
#  '레드와인',
#  '화이트와인',
#  '힙합',
#  'sperry',
#  'sperrykorea',
#  '스페리',
#  '가을스니커즈',
#  '데일리룩',
#  '멋스타그램',
#  '팬텀더화이트',
#  '팬텀',
#  '화이트위스키',
#  '룩스',
#  '메이크업카메라',
#  'looks',
#  'citylooks',
#  'makeup',
#  'makeupselfie',
#  'selfie',
#  'ルックス',
#  'メイク',
#  'ビューティー',
#  '양주',
#  'yu',
#  'yu샴푸',
#  '유샴푸',
#  '도그비잉코리아',
#  'dogbeingkorea',
#  '강아지샴푸',
#  '고양이샴푸',
#  '천연샴푸',
#  '강아지목욕',
#  '개스타그램',
#  '몬디의직딩라이프',
#  '카톡',
#  '카톡이모티콘',
#  'Mondi',
#  'b612',
#  'b612고양이',
#  '장화신은고양이',
#  'catstagram',
#  '비디오',
#  'video',
#  '안나카바',
#  '웨딩와인',
#  '브라이덜샤워',
#  '와인',
#  '스파클링와인',
#  'selfiecamera',
#  '얼스타그램',
#  '카메라앱',
#  '다운펌',
#  '다운펌약',
#  '젠틀피버',
#  'gentlefever',
#  '옆머리',
#  '헤어',
#  '헤어스타일',
#  'hair',
#  '데일리스킨',
#  'dailyskin',
#  '딸기우유비누',
#  '천연비누',
#  '여드름관리',
#  '거품',
#  '비누',
#  '바나브',
#  'vanav',
#  'UP5',
#  '뮤직테라피',
#  '갈바닉',
#  '뷰티디바이스',
#  '셀프뷰티',
#  '홈에스테틱',
#  '하기스수딩케어',
#  '바잇미',
#  '수제간식',
#  '강아지수제간식',
#  'buy2give1',
#  '유기견후원',
#  '멍멍이',
#  '야옹이',
#  '#테스트',
#  '망고링고',
#  '달달하게망고한잔',
#  '하이트',
#  '하이트망고링고',
#  '과일맥주',
#  '맥스타그램',
#  '라스토리아1001',
#  'Lastoria1001',
#  '이탈리안',
#  '화덕',
#  '화덕피자',
#  '파스타',
#  '서판교맛집',
#  '분당맛집',
#  '판교도서관',
#  '운중동맛집',
#  '+당일먹게되는 메뉴 이름을 해시태그로',
#  '아카디아',
#  '아카디아코리아',
#  '9월축제',
#  'EDM페스티벌',
#  '스티브안젤로',
#  '막제이',
#  '덥비젼',
#  '알리앤필라',
#  '코안사운드',
#  '스키즘',
#  '루디멘탈',
#  '옐로우클로우',
#  '딸기비누',
#  '테네비스',
#  'tenevis',
#  '효도',
#  '발바닥',
#  '기능성',
#  '기능성신발',
#  '고무팩',
#  '프리미엄팩',
#  'rubbermask',
#  '스펠',
#  'RTD와인',
#  '미니스파클링와인',
#  '미니와인',
#  '데일리스킨 ',
#  '특이한케이스',
#  'iphoncase',
#  'instagood',
#  '새티스',
#  'satis',
#  '화이트닝크림',
#  '라빠레뜨뷰티',
#  '라빠레뜨뷰티올인원세럼',
#  '동안뷰티',
#  '시간을초월하는아름다움',
#  'lapalettebeauty',
#  '올인원세럼',
#  '라빠레뜨뷰티슬리핑팩',
#  '슬리핑팩',
#  '로서울',
#  'rohseoul',
#  '가방',
#  '패션스타그램',
#  '패피',
#  '#영상',
#  '티톡스클렌저',
#  '폼클렌징',
#  'GentleMask',
#  '얼굴',
#  '세안',
#  '트러블',
#  '스토리지',
#  '바이닐앤플라스틱',
#  'Storage',
#  '여름휴가준비',
#  '휴가필수템',
#  '완소템',
#  '푸우쿠션',
#  '미키쿠션',
#  '괴물쿠션',
#  '몬스터쿠션',
#  '시작의여름',
#  '브라운아이드소울',
#  '러블리즈',
#  '영준',
#  '류수정',
#  '여름',
#  '한여름사랑의시작',
#  '미디언스맛집탐방',
#  '동네맛집',
#  '숨겨진맛집',
#  '플라네타리움레코드',
#  '케이지',
#  '널봐',
#  '정진우',
#  '지금여기',
#  'SHINE',
#  '토레타',
#  '과채수분음료',
#  '채워바나나',
#  '자신이만든[ㅏㅏㅏ맛우유]문구',
#  '에잇세컨즈',
#  '스튜디오에잇',
#  '8seconds',
#  'studio8',
#  '가로수길',
#  '하상욱',
#  '김규형',
#  '미닛메이드',
#  '미닛메이드 홈스타일',
#  '삼둥이주스',
#  '삼둥이',
#  '나를 위한 보상',
#  '천연테라피',
#  '클렌저',
#  '브레스킨',
#  '수제비누',
#  '유아용 비누',
#  '피테라',
#  '미스트',
#  '베이직하우스',
#  'Basichouse',
#  '면바지',
#  '피자',
#  '피자헛',
#  '슈퍼치즈바이트',
#  '맛있다',
#  '신메뉴',
#  '먹스타그램 ',
#  '치즈 ',
#  '배고파',
#  '시몬스',
#  '엔써리투',
#  'n32',
#  '침대',
#  '기본',
#  '남방',
#  '팔도',
#  '왕뚜껑',
#  '컵라면',
#  '팔도 왕뚜껑']

# %%
# 저장
data ='' 
with open('./data/hashtag/md_cpm_hashtag_preprocessed.txt', 'w', encoding='utf-8') as f :
    for word in tags : 
        data += word+'\n'
    f.write(data)
    f.close

# %%
# tag analyis에 있는지 확인
import requests
import json
api = 'https://b8k9yk75eb.execute-api.ap-northeast-2.amazonaws.com/tag_api/tag-analysis/tag-similar-request-by-name'

# %%
for i, word in enumerate(tags) : 
#     if i > 10 : break
    try :
        params = {'p':word}
        request_data = requests.get(api, params=params).text
        json_data = json.loads(request_data)
        if 'errorType' in json_data :
            print(word)
    except Exception as ex : 
        print(ex)
# Out:
# 듀오안
# 신바이오틱스뉴리더
# 박서준요거트
# 꼬불냉면
# 생면식감마라탕면
# 한화이글스마라탕면
# 포기하지마라탕면
# 내추럴더마프로젝트
# 시카바이오플라센타크림
# 자연을담은더마
# 피부트러블개선
# AMUSE
# 뉴트로매트
# 나르시즘
# 1998
# 썸머파이널세일
# 유니클로세일
# UNIQLO
# Summersale
# 로제타스톤
# 영어스피킹
# 코로니타
# 한입보틀
# 미니코로나
# 코로니타엔라임
# 코로나엔라임
# 10분휴가
# 일상속여유
# 맥주테라피
# 산토리맥주
# 산토리프리미엄몰트
# 산토리카오루에일
# 산토리뉴크리미서버
# 노워시
# 일본프리미엄맥주
# 크리미맥주
# 홈프리미엄
# 홈다이닝
# 건면
# GS25
# 심야포차국수
# 편의점음식추천
# AD
# VDL
# 퍼펙트핏파운데이션
# 씬님
# VDL팝서퍼컬렉션
# VDL썸머컬렉션
# 팝서퍼컬렉션
# 트리플샷
# 트리플컬러립
# SPONSERED
# 에어리매트
# 글로우매트
# KATE
# THEBASEZERO
# 더베이스제로
# 시크린스킨메이커
# 파우더리스킨메이커
# 켈로그
# 첵스
# 첵스초코
# 첵스초코마시멜로
# 첵스초코 AR에디션
# 첵스초코증강현실체험팩
# AR
# 증강현실
# 맥도날드아이스크림
# 베리스트로베리
# 파인애플칠러
# 디픈
# 소유마스크팩
# 1일1팩효과
# 극세사시트
# diipn
# 체크앤바이
# checknbuy
# 홈키파홈매트
# 홈키파
# 홈키파마이키파
# 홈키파캠핑에어졸
# 캠핑에어졸
# 모기기피제
# 요하임
# 어린이간식
# 가족간식
# 요거트
# 요거트추천
# 맛있는요거트
# 언더암케어
# 드라이콤포트
# 엑스트라화이트
# 퍼퓸데오드란트
# 패뷸러스플라워
# 스플래시라임
# 매직펄
# 퍼퓸데오
# 애플폭스
# applefox
# 여우도반한달콤한청량감
# 2XU
# 투엑스유
# 너를두배로
# 블랙클레이마스크팩
# 피지각질제거
# 모공팩추천
# 살브크림
# 연고크림
# 복합성
# 세상을바꾸는치킨
# 텍스트가이드확인하여 기입
# Becomeanicon
# 꿈은단절되지않는다
# 스텔라한잔
# 아이콘투아이콘
# 스텔라기부캠페인
# 트윈워시댄스챌린지
# LG트롬트윈워시
# 트롬세척기
# 트윈워시
# LG세탁기
# #sponsored_by_엘지
# 아레나코리아
# 아레나수영복
# 당근패드
# 사전구매
# 울트라모이스처핸드크림
# 향좋은핸드크림
# 건조한손
# 파우치잇템
# 슈퍼콘댄스
# 손흥민춤
# 슈퍼콘댄스챌린지
# DGSMEG
# SMEG
# 다이치
# 다이치유모차
# 다이치루이
# 다이치유모차앨리
# 다이치루이유모차
# 다이치앨리
# 유모자추천
# 다이치아기띠
# 바르다김선생
# 바르다김선생신메뉴
# 김선생신메뉴
# 치즈가락떡볶이
# 순메밀회냉면
# 무나물꼬막비빔밥
# 레디고신세계
# readygoshinsegae
# 달바바디미스트
# 글로우바디미스트
# ThinQ
# LG씽큐
# 씽큐라서땡큐
# 학과피로
# OO학과(자신의학과또는전공)
# 모카라디오
# 맥심모카라디오
# 맥심모카골드
# 비디샴푸
# TS샴푸
# TS
# TS비듬샴푸
# TS비디샴푸
# BD샴푸
# 비듬관리
# 머리가가려울때
# 요즘단백질
# 농심켈로그
# 프로틴그래놀라
# 미숫가루콩앤검정약콩
# 요거트큐브앤베리
# 파인애플스트로우데코
# WTRD
# 남자샌들
# 남자슬리퍼
# 플립플랍
# 뉴케어
# 뉴케어액티브
# 사코페니아
# 식사대용식
# 플레이롭스
# 롭스핵인싸춤
# 홈솔루션
# 마이키파엑스트라파워
# 리퀴드전자모기향
# 굿나잇솔루션
# ELLEFIT
# 엘르핏
# 엘르수영복
# AR댄스페스티벌
# 유플러스5G
# OOO(해당가수이름)
# 달바미스트세럼
# 달바미스트
# 승무원세럼
# 꼭써야한다면
# 나를위해지구를위해
# 불편한가방
# 풀무원의1
# 유니클로감사제
# 멘토스
# 멘토스플레이그라운드
# 멘토스슬라이드
# 자이언트멘토스
# 메가박스코엑스
# 오레오데이
# 5월25일은오레오데이
# OREODAY
# 우리사이오래오래
# 오레오스노우스티커
# #유료광고
# #AD
# 오늘의언더암케어
# 롤온
# 아몬드후레이크
# 아몬드후레이크이벤트
# 르크루제시리얼볼
# 시리얼추천
# 시리얼볼
# 에어리즘을입는100가지이유
# loveAIRism
# 유니클로에어리즘
# UNIQLOLifeWear
# AIRism
# 에어리즘브리프
# 트란시노2
# 먹는기미치료제
# 민낯인생샷
# 8주프로젝트
# 보령제약
# 기미치료제
# 더아이컬러
# 케이트섀도우
# 싱글섀도우
# 데일리섀도우
# 슈퍼샤프라이너EX
# EX2.0
# 극세사아이라이너
# 잡스
# ZAPS
# 아웃도어미스트
# 버드500ML
# MT
# 메이드바이유
# 스킨클리닉
# made_by_you
# 마데카팩
# 미세먼지심한날
# 여행가방싸기
# 실키오일세럼
# 극손상모환생
# 환생세럼
# 커리쉴
# 커리쉴클리닉
# 미용실추천템
# 원장님추천템
# BeAKing
# 타투전시회
# 자유가있는곳에
# 아라아트센터
# 프리웨이브
# 봉산동카페
# prewave
# 스트로베리콘
# 솔티카라멜콘
# 솔티카라멜맥플러리
# illelan
# 일레란느
# 일레란느팝업
# 일레란느주얼리
# 룸바이홈
# 룸바이홈침구
# 롯데마트룸바이홈
# 알러지케어
# 안티알러지이불
# 알러지케어이불
# 가성비이불
# 클릭바틀
# 미정
# KingofLCC
# 시크리스킨메이커
# seaNtree
# 입술보톡스
# 달바선크림
# 에센스선크림
# 뿌리는마스크팩
# 뿌마
# 달바뿌마
# 올리브영마스크팩
# LG스타일러
# LG트롬건조기
# Visa
# 비자
# takeyourvisa
# CHECKYOURVISA
# TAKEYOURVISA
# 해시태그추가될예정
# VISATIME
# LETSVISA
# 비자여행
# VISA
# TravelwithVisa
# Visa카드
# 3가지어니언조합
# 시그니처버거신제품출시
# 잼아저씨
# 개러지라이브
# VLIVE
# Kpop
# 프링글스미스터리맛
# 프링글스신제품
# 프링글스이벤트
# PRINGLES
# UniqloU
# 유니클로U
# OOTD
# MTD26
# MCURIE
# m.curie
# Idol
# 피넛버터오즈
# 멈출수없는아는맛
# 피넛버터오즈모먼트
# 오즈의나라
# 시리얼레시피
# 곡물시리얼
# 오즈링
# 오즈맨
# 신제품시리얼
# 시리얼이벤트
# 발라드추천
# 라면
# 신상라면
# 풀무원
# 생면식감
# 생라면
# 건면
# 어그로
# 튀기지않은
# 원조
# 대세라면
# 생면부심
# 신라면건면
# 시조새
# 갓뚜기
# 하이드로겔팩
# 영화파이브피트
# 네이쳐라이프
# 매콤꼬막과제육볶음
# 매콤불닭
# 매콤제육볶음
# 냉동안주
# 3분조리
# 전자레인지3분
# 5G는유플러스샵
# 오지는_어드벤처
# 오지는어드벤처
# 유플러스샵
# 유플러스샵_5G
# 지조
# 더쏘나타라이브
# 오빠쏘나타
# 숨랩
# 숨랩마스크
# 숨쉬는초청정마스크
# 쿨린
# 쿨린선풍기
# 허니콤선풍기
# USB선풍기
# 벌집선풍기
# 벌집망선풍기
# 회사선풍기
# 무자극바람
# 무자극선풍기
# 맥도날드디핑소스
# 이집소스잘하네
# 완딥
# 맥너겟
# 1가구1에릭남
# 취향저격쏘나타
# 먼싱웨어
# munsingwear
# 헬로아이엠피트
# 먼싱웨어피트
# 피오니브라이트닝안티에이징크림
# 피오니크림
# 20초크림
# 비타민B9톤업크림
# 수분톤업
# 썡얼크림
# 데저티카콜라겐모이스처라이징크림
# 콜라겐크림
# 대우건설
# PRUGIO
# 프리미엄파티
# 브랜드리뉴얼
# 2019푸르지오
# 슈레피
# Surepi
# 슈레피샤워필터
# 스킨케어필터
# 콰트로필터
# 프리미엄샤워필터
# 더히스토리오부후
# WHOO
# 비첩자생에센스
# 자생웨이브
# 로얄안티에이징
# 안티에이징에센스
# 필수에센스
# 자생력
# 1위에센스
# 만우절
# 쿠폰사생대회
# 유니클로CSW이벤트
# 오피스만렙
# 지금부터재테크는
# 엔화로갈아탄다
# 엔화재테크
# 엔화
# 환율
# 안전자산
# 환테크
# 일본주식
# 영화로망
# 루나스틱파데
# 동서식품
# 도라지작두콩차
# 건강에좋은차
# 몸에좋은차
# 미세먼지에좋은차
# 환절기에좋은차
# 마시는차추천
# 미세먼지많은날도라지작두콩차
# 호흡기에좋은차
# 3355코로나
# corona
# 코로나슬릭캔
# 슬릭캔
# CoronaSleekcan
# 아이스버킷
# 코로나버킷
# 코로나모임
# 코로나협찬
# 하루한줌아몬드
# 뷰티습관
# 먼데이키즈
# 이진성
# 먼키
# 3월공연
# 콘서트그램
# 웨딩북
# 웨딩북청담
# 웨딩북스드메
# 엔조최재훈골드라벨
# 피톤케어
# 피톤케어맨
# 새해선물추천
# 멘토스각
# 이럴때멘토스각
# oo할때(상황묘사)
# Refresh
# 츄파춥스
# 츄파펀콘서트
# 츄파아일랜드
# 자이언트롤리
# 자이언트츄파춥스
# 너랑코로나
# 아이마이밀
# 오트밀크
# 아웃도어맥주
# 코로나캔
# 오스바이오
# 오스케어
# 캡슐마스크팩
# 오스케어장미팩
# 케어놀로지
# 리블루미스트
# 리블루밸런싱크림인미스트
# 약산성미스트
# 크림미스트
# 디트로네라운지
# 잠실브런치
# 비오코스
# BIOCOS
# 24K골드
# 24K골드퍼펙트
# 앰플팩
# 1일1앰플팩
# 멘토스릴레이
# 신세계사이먼아울렛
# 신세계사이먼부산
# 카페간식
# mbnyforum
# 엠비엔
# 와이포럼
# 지금시작하라
# 두드림
# 영웅쇼
# 앵커쇼
# 두드림쇼
# 미래쇼
# 눈높이러닝센터
# 공부초능력
# 눈높이공부초능력
# 성장리포트
# 4력
# 초등학원
# 자립학습
# 기초학력
# 소소풀
# 소나무팩폭
# 소소풀수풀마스크
# 텍스트가이드참고
# 오티스의비밀상담소
# SexEducation
# ShowUniqloU
# UniqloLifeWear
# 현대백화점DUTYFREE
# 슈레피워터탭
# 워터탭
# 수도꼭지필터
# 수도꼭지캠페인
# 2019설
# 설연휴
# 명절디저트
# 설날음식
# 질경이
# 질경이데일리에코아워시퓨어폼
# Y존클렌저
# 여성청결제질경이
# 김소은
# 디자인포트폴리오
# 추후안내예정
# 눈높이CF영상
# 눈높이성장판
# 눈높이성장리포트
# 4력퀴즈이벤트
# 듀플로
# 유아용레고
# 자동차세트
# 헬리콥터놀이
# 인공지능영화관
# 롯데시네마건대
# 롯데시네마건대입구
# 유나뷰스터
# 뷰티유튜버유나
# 뷰티클라우드유나
# LG
# 디오스
# DIOS
# 어디에살든
# 나답게살자
# 직방이벤트
# 컬러핏립스틱
# 아이오페컬러핏립스틱
# 신민아립스틱
# 컬러핏립스틱글로우
# 고발색
# 쫀쫀밀착
# 맑은발색
# 촉촉광택
# 매끈탄탄
# 나이트케어추천
# 듀얼액션
# 차오르는수분
# 탱탱해진피부
# 하이알루론나이트필링앤세럼
# 육시칼퇴
# 육시칼퇴챌린지
# 풀무원육칼
# 새해계획
# 신년계획
# 2019년계획
# 2019년목표
# 놀춤
# 아리얼마스크팩
# 무드메이커
# 무드메이커마스크
# 디데이마스크
# 마스크시트
# 그대이름은장미
# 배꼽빠짐
# 사랑해요장미
# 1월16일대개봉
# 말할수있는비밀
# 온라인서점3개중택1
# 데상트터보
# 유리프
# youlief
# 출근토너
# 에센스토너
# 환절기스킨케어
# 출근러
# 촉촉보습
# 1분긴급수분
# 역삼동고시원
#  역삼동원룸
#  작심하우스
#  직장인원룸
#  강남구원룸
# 보드게임영상통화
# WAVE
# 캐치마인드
# 추천앱
# 실종아동찾기
# 조하늘
# 최진호
# 박동은
# 실종아동찾기센터182
# 세상에서가장큰아이
# 골든그래놀라
# 골든그래놀라레드빈그린티
# 녹차시리얼
# 포스트시리얼
# 그래놀라시리얼
# 시리얼신제품
# 클룩
# 클룩점프
# Klook
# 여행을클룩하다
# 도시명(여행지)
# 피자헛4030랩
# 피자헛모델
# 피자헛광고
# pizzahut
# 피부과쿠션
# 레노덤쿠션
# 데이롱비비크림
# 핸즈업커피
# 에그와플
# 놀이터브릭박스
# 브릭박스
# 대교
# 성장리포트인터뷰영상
# Ulike
# ULikeHalloQueen
# HorrorQueen
# HalloweenMakeUp
# 눈높이4력영상
# 제2의엄마
# 너도나도감사한마음
# 이벤트홍보
# 근감소
# 육아몸매관리
# 콘푸라이트
# 오곡코코볼
# 새로워진포스트
# LG코드제로A9물걸레
# LG코드제로A9
# LG무선청소기
# 혼수선물
# 쿡캔55가지레시피
# 마약왕
# 12월19일대개봉
# 킨트
# 킨트주얼리
# KINT
# 킨트레드박스
# 오르빗컬렉션
# 데일리목걸이OR데일리귀걸이(해당제품의해시태그)
# 포인트목걸이OR포인트귀걸이(해당제품의해시태그)
# 예쁜청소기
# 신년모임
# THENEWMALIBU
# Chevrolet
# 비교시승
# 중형세단
# Carstagram
# 아임리얼
# 순수착즙
# 리얼과즙
# 천연과일주스
# imreal
# realjuice
# 손상케어
# 현실주의스킨케어
# 뉴트리탄앰플
# #HERA
# 로지사틴크림
# 헤라클렌징티슈
# 럭셔리티슈
# 완결크림
# 수분결크림
# 디자인어워드
# 메이크업필러
# 벨로테로
# 메이크업쇼
# 멀츠코리아
# Merz
# serendipityjourney
# MASJ
# 꿀잠오일
# 스킨미소
# 개기름지우개
# 노세범
# skinmiso
# 아몬드뷰티스튜디오
# N서울타워
# 산타클룩스
# 도시명(여행했던 지역명)
# 더참치togo
# 즉석요리
# 참치다이어트
# 파우치참치
# 동서벌꿀
# 꿀바른생활
# 겨울아이템
# 100퍼센트꽃꿀
# 꿀레시피
# 꿀활용법
# 사전포스팅/방문인증 포스팅 별 해시태그가 다르니 가이드 참고하여 삽입해 주세요!!
# 칼퇴는권리
# StellaArtois
# 아침간식
# 저녁간식
# 포스트그래놀라
# 그래놀라센서리지퍼백
# 센서리지퍼백
# 에버그로
# 빙그레펫밀크
# 에버그로펫밀크
# 빙그레에버그로펫밀크
# 달바세럼
# 항산화세럼
# 항산화아이크림
# dalba
# 현대홈쇼핑_달바
# 달바홈쇼핑
# 버츠비
# 홀리데이에디션
# @hddfs.official
# 금손포토스팟10
# 장소명(예-삼성역포토스팟 그대로복사하지마세요)
# 프리미엄독서실
#  독서실추천
#  작심독서실
#  공스타그램
#  공부인증
# 작심독서실OOO점
# AHC
# 미니멀10
# AHC미니멀10
# AHC워터리에센스
# MAKEMERARE
# RAREKIND
# BERAREKIND
# lipcraver
# 립크레이버
# 솔어바웃
# soleabout
# #팝업인증샷
# 뽐뿌뽐뿌
# TEAM다운
# GUOUTER
# GUstyle
# GU데일리룩
# GUKorea
# GUAD
# GU광고
# TEAM울
# 제품마다 상이합니다!! 텍스트 가이드를 참조해 주세요!
# 풀무원아임리얼
# 아임리얼굿즈
# 아임리얼에코백
# 아임리얼링거치대
# 연말선물추천
# 프코
# 프코샐러드
# 프코한끼
# 샐맥
# 슈퍼킵라이너
# 처음그대로keep
# NoMoreTouch
# 히로인메이크스무스리퀴드라이너슈퍼킵
# 워터프리카라
# 바를땐_워터프루프
# 지울땐_리무버프리
# 히로인메이크어드밴스드필름마스카라
# 피키이터
# 피키이터역삼
# 슬리핑뷰티112
# 매일밤피부잠금
# 예뻐지잠
# 쿨쿨케어
# 인싸밤케어
# 숙면피부
# 슬리핑뷰티템
# 슬리핑뷰티템추천
# 아자르
# 요즘핫한어플
# Azar
# 영화간식
# 영화관간식
# 빙그레슈퍼콘
# 슈퍼콘초코
# 슈퍼콘바닐라
# 슈퍼콘광고
# 코아페
# 코오롱몰아우터페스티벌
# 설리캔디코트
# 겨울인싸되기
# 소원슈에뜨
# 소원인형
# 북유럽포트
# 2도디테일
# 전기포트
# byseries
# 247덕다운롱패딩
# 24시간7일입어도편한
# 247
# 데일리웨어
# 아기띠패션
#  힙시트아기띠
# 특허받은아기띠
# 다이치광고
# 힙시트추천
# 힙시트아기띠
# 완전편안한힙시트
# NIVEA
# 믹스미
# 니베아믹스미
# 바디앤핸드크림
# 나만의향나만의색깔
# heattech
# 유니클로히트텍
# 히트텍
# 달빛유자
# 달빛다방
# 달빛유자수면팩
# HANYUL
# 그림의힘
# 그림의힘2
# 수능선물
# 맥도날드시그니처멤버스
# 인마이백
# 제품브랜드명을입력해주세요
# 받으신제품명을입력해주세요
# 이효리화보
# 어딕션윈터
# 시누아즈리
# 레드중독
# 엠파이어패션
# 더아이섀도우128
# 레드범벅
# 엠프레스오키드
# 리퀴드아이라이너13
# 코오롱아우터페스티벌
# 브랜드명을입력해주세요
# 제품명을적어주세요
# 오레오오즈
# 초코시리얼
# 소프트크림치크
# 소크치
# 남성에센스
# 남자에센스
# 군용
# 레드칙
# 요즘은이런식
# 어성초크림
# 겨울필수템
# 헤이네이처
# 사회적메세지
# 지디11
# 시카셀
# #WISHtoThinQ
# #LG씽큐
# #LGThinQ
# #인공지능가전
# #제작비지원 by #LG전자
# 아침에주스유기농
# 아침에유기농
# 아침에주스오가닉
# 포도주스
# 아침에주스
# 옵티프리
# 알콘
# 렌즈세척액
# 깐깐한렌즈관리용액
# 따가움없이
# 전세계판매1위
# 수분막형성
# 한달렌즈
# 에어렌즈
# 삼분의일매트리스
# 삼분의일부산
# 온도조절포트
# 커피포트
# 노란탄력포텐
# 유해성분NO
# 지퍼락
# 지퍼락이지오픈탭
# 본인의 활용방법과 관련된 해시태그(여행준비등)
# 별반짝이는꽃
# 나의찬란했던순간_혜화
# ZNE
# FASTRELEASE
# 준비된단한번의움직임
# 브라운면도기
# 브라운시리즈9
# AI면도기
# 전기면도기추천
# 남자면도기추천
# 전기면도기순위
# 면도기선물
# giftfromBraun
# 브라운제공
# 브라운시리즈7
# Wellage
# HA원데이키트
# 스페셜케어
# 웰라쥬지원제품
# 후기는솔직하게
# 영화휴게소
# 재희
# VOD개봉
# 극장동시
# 양수빈
# 영화휴게소
# 클로렐라
# 면역엔클로렐라
# HealthyGreen
# 메르스
# 메르스조심
# 메르스예방
# 마이밀
# 아침대용식
# 속편한식사대용식
# 미래형식사
# 셀프사진관
# 인생화보
# 데상트영애슬리트
# 깔라만시패드
# 비타민듬뿍
# 피부톤업
# 노폐물배출
# 윤기촉촉
# 간편관리
# 뷰튜버추천
# 영유아를위한레고
# 추석지퍼락
# 추석음식준비
# 리큅
# 식품건조기
# 프리미엄주방가전
# 리큅이벤트
# 행운의1인
# 결정흔들리지않고마음먹은대로
# 결정책
# 결정습관
# 결정잘하는법
# 프로결정러
# 헛개초코밀크
# 달콤한해장엔
# 손글씨_응원릴레이
# 제주동중_사이클팀
# 디오스냉장고
# LG전자
# 다이슨슈퍼소닉
# 노답피부
# 더마리페어시카크림
# 시카크림효능
# 응원쓰기_릴레이
# 제주동중싸이클팀
# 샹프리
# 샹프리마린쥬얼캡슐
# harrods
# harrodsbeauty
# shangpree
# 마린쥬얼시트마스크
# 이클립스
# 이클립스민트
# 이클립스캔디
# 민트캔디
# CU에서구매
# 오늘의건강
# 오늘의장
# 오늘템
# 에잇템
# 책상위작은밭
# 책상위작은밭양배추사과즙
# 책밭즙
# 양배추사과즙
# 양사즙
# 즙
# 즙스타그램
# 책상위작은밭호박즙
# 호박즙추천
# 건강한모발
# 콘푸라이트사랑충전소
# 원조시리얼
# 가족시리얼
# Labnosh
# 이것이식사다
# atem
# 그로서리서울
# 밤간식
# 단호박죽
# 호박죽
# 육개장죽
# 인생책
# 마듀
# 자음생에센스
# 자음생
# 인삼에센스
# 캡슐에센스
# 탄력각
# HelloGoldMorning
# MyResetMoments
# 푹못잔건비밀
# TimeToReset
# 카스랑놀자
# CBP2018
# CBP
# 카스블루플레이그라운드
# CASSBLUEPLAYGROUND
# Cass
# 카스프레시
# CassFresh
# 블루모지
# heineken
# worldclass
# 펜타포트락페스티벌
# 펜타포트
# 2018펜타포트
# LIVEYOURMUSIC
# #프로틴바
# apmall
# 아모레퍼시픽몰
# 아몰
# 인마이백릴레이
# 인마이파우치
# 아몰이벤트
# IGO신남
# 스튜디오S
# 인생프사
#  인생샷
#  신세계면세점강남점
#  신세계면세점
#  StudioS
# 신세계면세점강남점
# StudioS
# 매그넘아이스크림
# 매그넘플레져스토어
# 진한즐거움에빠지다
# 매그넘서울
# MAGNUMSEL
# 터치후레쉬
# 화장실냄새제거
# 화장실방향제
# 셀루닉
# 래디언스퍼밍크림
# 광채탄력크림
# 광탄력크림
# CU
# 목요일발표예정
# #언더100
# 아워홈
# 윤아더하기
# DB다이렉트
# 유플러스알뜰모바일
# U알뜰모바일
# 홈플러스요금제
# 요금제추천
# 통신비
# 알뜰폰요금제
# 홈플러스요금
# 홈플러스신제품
# 하임셰프
# 뽀드득
# 멸균
# 비플랫
# 세상편한피부관리
# 슬리핑마스크
# 시카성분
# beflat
# 시카1000ppm
# 카페스노우
# haveanicesnow
# 홍대냉장고
# 던킨도넛
# JMT
# 야놀자이벤트
# 초특가야놀자
# 너도하니나도하니
# 스노우이벤트
# 블루문풀파티
# 블루문맥주
# Hi5페스티벌
# 반얀트리풀파티
# 블루문파티
# 카스미니캔
# CassMiniCan
# 카스프레시250
# 점심시간엔CassMini
# 원샷캔
# 작으니까좋아
# 비브라스쇼케이스
# 비브라스
# vivlas
# 추자현마스크팩
# 보아립밤
# BOA
# 보아공연
# 보아마스크팩
#  100%
#  under100
#  아워홈
#  오늘부터내밥
# #유세린
# #eucerin
# #더모퓨리파이어
# #오일컨트롤
# #트러블독립선언
# 대구치맥페스티벌
# 대구치맥
# chimacfestival
# 치킨앤카스
# 치킨엔카스
# 카스브랜드데이
# CASSBrandDay
# 치킨에는Cass
# 알뜰모바일
# GS25요금제
# GS25추천
# GS25요금
# 랄라블라요금제
# 랄라블라요금
# 랄라블라신제품
# 베이비프렌즈
# 픽처하우스
# 베이비프렌즈추천상품
# 유아용추천도서
# 신개념영상통화
# Wave
# 우리가노는법
# 최대8명
# 뻬딱구두
# 수제화브랜드
# 이태리천연가죽
# 프레시코드신메뉴
# 분짜샐러드
# 쉬파샐러드
# 프코스팟
# 알페신
# alpecin
# 독일샴푸
# 독일의기술력
# eucerin
# 더모퓨리파이어
# 오일컨트롤
# 트러블독립선언
# 화산송이
# 얼굴청소
# 100인체험단
# 수퍼체험단
# 화산송이체험단
# 모공청소기
# 이니스프리모공팩
# 미샤파우치인클리어백
# 미샤PVC백
# 얼청타임
# 아묻따모공팩
# 바나나맛우유뽑기
# 함께놀아요
# 빙바
# 단지우유
# 프레민트치약
# 프레민트
# 민트치약
# 이니스프리슈퍼푸드
# 슈퍼푸드소확행
# 슈퍼푸드블루베리라인(제품에따라달라질수있음)
# 박나래클로렐라
# 면역력발사
# 톰크루즈
# 미션임파서블폴아웃
# 본인이수령한제품명을입력해주세요
# 티오피
# 트리플에스프레소라떼
# 발렌타인파이니스트
# 발렌타인파이니스트하이볼패키지
# 베링
# 맥심티오피
# 나만의티오피
# 티오피익스플로링
# 티오피10주년
# 시그니처블랙
# 맥심플랜트
# 티오피팝업스토어
# 맥심플랜트팝업스토어
# 한남동핫플
# 안된다는생각
# 뒤집어버려
# 월드컵공식맥주
# 2018FIFA러시아월드컵
# 뒤집어바
# Worldcup
# 베버시티스틱
# 베버시티
# 세미기업
# 뽑픽
# 그랩픽
# grabpic
# 사진앱
# 필름앱
# 밀착사진
# 디지털필름
# 데이24
# 본인의컨셉해시태그(예:심쿵24관종24일상24등)
# #프레민트치약
# #프레민트
# #치약
# #치약추천
# #프리미엄치약
# #민트치약
# #집들이선물
# #구취제거
# #여행
# #선물
# 쉬어래스팅
# 쉬어래스팅룩
# 쉬어래스팅젤쿠션
# 설화수쿠션
# 쉬어래스팅쿠션
# 보송화사
# 쉬어래스팅메이크업
# 송혜교메이크업
# 올때메로나칸탈루프
# 올때메로나
# 메로나칸탈루프
# 올때메로나튜브
# 메로나튜브
# 수아도르
# 친절한브러씨
# SOOADOR
# RISABAE
# 인화사진
# DAY24
# 사진선물
# 친구24심쿵24관종24중본인에게해당하는미션해시태그
# 야놀자초특가
# 야놀자하니
# 인생경기공유이벤트
# 알페신이벤트
# All_About_Steak
# 팩스테이크
# 홈스테이크
# 홈스
# 헤비시즈닝스테이크
# 돈스파이크
# 티오피10주년축하해요
# 홈핏
# 홈요가
# 홈트족
# 홈피티
# 좋은것은오래갔으면좋겠습니다
# 버넬
# vernel
# 버넬10주간의향기
# 10글자열정댓글이벤트
# 바이탈뷰티
# 입은즐겁게몸은가볍게
# PK마켓
# IPA
# 화수브루어리
# 버드나무브루어리
# 크래프트루트
# 속초IPA
# #LGTHINQ
# #IMAGINEYOURDAY
# #전시
# #성수
# #바이산
# #BAESAN
# 개들의섬
# 6월21일개봉
# 웨스앤더슨
# 외에2개이상자유롭게추가해주세요
#  #IMAGINEYOURDAY
#  #전시
#  #성수
#  #바이산
#  #BAESAN
#
# #씽큐
#  #엘지씽큐
#  #씽큐전시
# 친구24심쿵24관종24중본인의미션에해당하는것1
# 블루문위크
# bluemoonweek
# 블루문생맥주
# 오렌지가니쉬
# bluemoonbeer
# #블루문
#  #bluemoon
#  #블루문위크
#  #bluemoonweek
#  #블루문맥주
#  #블루문생맥주
#  #오렌지가니쉬
#  #bluemoonbeer
# 6월21일대개봉
# 하비풀
# 유미의세포들
# 미니어처하우스
# 출출이콘테스트
# 식기건조기
# 식기살균건조기
# 식기건조대
# 약국용화장품
# 프라우드메리
# 메리를만나면프라우드해집니다
# 보습립오일
# 식물성오일
# 프레시코드샐러드
# 잔류염소
# 스킨케어워터탭
# surepi
# 모든문제는물때문이었는지몰라
# beringtime
# 2018visafootballnight
# VisaKorea
# 2018VISAFOOTBALLNIGHT
# 달품애
# 달품애생리대
# 유기농생리대추천
# 낮보단밤에더보고싶어
# 김작가의이중생활X더부스
# 국민IPA
# 김작가의이중생활
# Beringtime
# 오직그대만
# 에그롤
# 대만수제디저트
# 그대만의대만
# 독전
# 갓띵작
# 심플리스무스
# 티오피심플리스무스
# 스무스하게잘넘겼어
# 스무스하게넘겨툰
# 스무스키트
# 심플리스무스키트
# 드립배틀
# GO100ASIA
# 아시아를자유롭게
# 쿠알라룸푸르를자유롭게
# 뷰티피플
# BEAUTYPEOPLE
# 철벽녀쿠션
# 철벽녀텐션쿠션
# 철벽녀쿠션2
# 텐션쿠션
# 철벽녀엔티크
# 마늘이의일기
# 브라벡토
# BRAVECTO
# 12주간의사랑
# 진드기예방
# 버넬10주
# 해초마스크
# 포키
# pocky
# UT
# sharehappiness
# pockyUT
# 밸런스온
# 밸런스온시트
# 밸런스온필로우
# 마동석방석
# 썬비
# 그림비
# TOP
# U플러스알뜰모바일
# 무제한데이터
# 썸부스터
# 스테이얼
# STAYERE
# 토일렛퍼퓸
# 시크릿커버퍼퓸
# 스테이얼핑크바디워시
# 핑크바디워시
# 바디브러쉬
# 드시모네베이비
# 내추럴더마프로젝트
# 스킨케어
# 기초화장품
# 수분크림
# 재생크림
# 톤업크림
# 데저티카콜라겐모이스처라이징크림
# 시카바이오플라센타크림
# 아미오그레인프리
# 아미오
# 풀무원아미오
# #작가의탄생
# #책만들기
# #그림책
# #작가
# #어린이작가
# #그림책만들기
# #그림책출판
# #육아스타그램
# #맘스타그램
# #육아
# #도치맘
# 대디북
# 마미북
# 삼우실
# 명민호
# 척하면_착_지이크파렌하이트
# 직장생활꿀팁키트
# 프로직장생활러
# 지이크파렌하이트
# 트리플과여행중
# triple
# 핫시리얼
# 오트밀레시피
# 오트밀먹는법
# 소이현인교진
# 소이현안교진
# 모닝와이드
# 3중기능성화장품
# PA++++
# 대디북마미북세트
# 미드추천
# 브라운시리즈5
# 브라운AI면도기
# 면도시간절약
# 독일면도기
# 면도기추천
# 피부보호면도기
# 면도방법
# 전기면도기입문템
# 면도보다중요한면도기
# 아침준비꿀템
# 쉬운면도
# 브라운시리즈3
# 스냅스
# 스냅스포토북
# 어버이날포토북
# 부모님포토북
# 앱솔루트엘릭스
# absolutelyx
# 24시간이편한
# 와이어리스브라
# 노와이어브라
# 인생브라
# 속옷추천
# 브라추천
# 여성속옷추천
# 디어달리아
# DearDahlia
# 대리석립스틱
# VeganFriendly
# CleanBeauty
# CrueltyFree
# 이사모아
# 이사
# 원룸이사
# 용달
# 이사어플
# 자취생
# 이사비용계산기
# 이사비용
# 이사준비
# 이사가자
# 재즈라운지
# 포지티브제로라운지
# positivezero
# 댕댕이여러분
# 냥냥이여러분
# 댕댕이보험
# 냥냥이보험
# 교보라이프플래닛
# 댕댕이보험이벤트
# 냥냥이보험이벤트
# 크론
# 가장눈부신지금
# 유스레볼루션
# 유스레볼루션래디언스컨센트레이터
# 정화안티에이징
#  재즈바
#  성수동
#  포지티브제로라운지
#  positivezero
# (제품명)
# VLAB
# 브이랩
# 발세정제
# 강아지발세정제
# 워터리스풋클린저
# 펫닥
# 설화수설린크림
# 송혜교매화크림
# 피부피로
# #24시간이편한
# #유니클로
# #와이어리스브라
# #노와이어브라
# #인생브라
# 달총
# 거짓말처럼
# DearDahlia
# VeganFriendly
# CleanBeauty
# 츄파FUN팩토리
# FOREVERFUN
# 여에스더
# 여에스더유산균
# 에스더몰
# 에스더포뮬러
# 멈
# Dok2샴페인
# DareWinCelebrate
# 멈추지않는도전
# MUMM
# 사브라지
# 호텔나우
# 프라이빗딜
# 우아솜메
# 우아솜메(제품명)
# 여행갈때뭐입지
# 트래블웨어
# 촉촉한자연보습
# 스페인올리브
# 피부기초체력
# 수분지속력
# 제임슨
#  위스키
# 아이리시위스키
# 세인트패트릭데이
# 맨솔
# mansole
# 아티스트콜라보
# 김병조
# PWAC
#  달총
#  감성스타그램
#  감성
#  새벽
#  새벽감성
#  노래추천
#  음스타그램
#  거짓말처럼
# GetCloser
# DUO
# DUO콘돔
# 스콘챔
# 닦아쓰는토너
# 유산균에센스
# 보라병에센스
# 미백주름개선화장품
# 응답하라오천만
# 응오
# 땡큐맘2018
# 2018평창
# 피앤지
# sponsoredbypg
# 모태보습
# 더블하트모태보습
# 태지보습
# 모태보습스킨케어
# 신생아워시
# 신생아오일
# 아기보습
# 더블하트모태보습스킨케어
# #디어달리아
# 시코르신세계강남점
# 마카롱팔레트
# mentos
# 멘토스초코
# mentoschoco
# 장미맨숀
# 멘토스초코샘플링
# 커피는멘토스와
# @airasia_korean
# 요리하다
# 만다복
# 백년짜장
# 하얀백년짜장
# 주말짜장면
# 힐링디너
# yorihada
# lottemart
# 초간편요리
# 효리네민박
# 효리네민박2
# 효리네민박토퍼
# 효리네토퍼
# 이효리토퍼
# 토퍼매트리스
# slou
# 타퍼
# 시디즈아띠
# 디즈니아띠
# 유아의자
# 정대세의자
# 대세의자
# @airasia_kroean
# 작가의탄생
# 어린이작가
# 아마존출판
# 평창동계올림픽
# 라이트업아이스링크
# 동대문아이스링크
# DDP아이스링크
# 라이트업유어에너지
# 현대차아이스링크
# 직장인추천도서
# 초보마케터
# 프리미엄콘돔
# 자연방목
# 남양아기치즈
# 드빈치
# 치즈요리
# 어린이치즈
# 에이치로즈
# 쉐이빙폼
# 함께했S
# FILA
# filatogether
# 자정미백에센스
# 동안에센스
# 해말간피부
# #응답하라오천만
#  #응오
#  #피앤지
#  #2018평창
#  #sponsoredbyPG
# #응오
# #피앤지
# #2018평창
# sponsoredbyPG
# #sponsoredbyPG
# EFC셔츠
# 유니클로셔츠
# 에브리데이셔츠
# 추후공개
# 쉬운캠페인
# 어서어서지원
#  바나나툰
# 레진코믹스
# 웹툰
# 추천
# 일상
# 일상스타그램
# 이지오픈탭
# 지퍼팩
# 소분
# 지퍼락상상하는대로사용하세요
# 음식물쓰레기버리는법
# 디어달리아쇼룸
# 듀얼팔레트
# 컬렉션세트
# DualPalette
# CollectionSet
# Dynafit
# BackToSchool
# Backpack
# 신학기신발
# 더블하트섬유세제
# 더블하트섬유유연제
# 더블하트세제
# 안심빨래
# 아기옷세탁
# 야노시호
# 야노시호진공샴푸
# 진공샴푸
# 야노시호샴푸
# 겨울철샴푸
# 트루엘
# 핑크세럼
# 히비스커스세럼
# 브랜드체험
# 히스토랩
# 미디언스
# 코인원
# LiveLoud
# LED벨로스터
# LED자동차
# LED퍼포먼스
# LED위장막
# 신형벨로스터
# 블링블링카
# 벨로스터터보
#  응오
#  피앤지
#  2018평창
#  sponsoredbyPG
# 유플러스우리집AI
# 우리집AI
# AI스피커
# 클로바프렌즈플러스
# clovafriendsplus
# LG유플러스
# 홈IoT
# 유플러스tv
# 오늘은풀러스로가자
# 풀러스
# poolus
# 카풀앱
# 틱톡틴트
# 블랙미러
# 알베르토자코메티
# 조각가
# 한국특별전
# 더블유드레스룸
# wdressroom
# 롤온향수
# 브라이트
# 카카오T
# 카카오T드라이버
# 카카오택시
# 신현희와김루트
# 대박콜라보
# 추후공지예정
# 플레시아
# 플레시아물감키트
# 내추럴치약
# 치약키트
# 레진코믹스
# 바나나툰
# OO역
# 그래서건강
# 에이비자르
# V리프팅팩
# 러플리코스메틱
# 연예인팩
# #조선미녀
# #꽃담
# #필링젤
# #1분 필링젤
# #1분
# #소녀 필링젤
# #소녀
# 어묵티
# 죠스어묵티
# 신생아젖병
# SofTouch모유실감
# 토이젖병
# 국민젖병
# 모유실감젖병
# @SKII
# YourStatementYourbottle
# SKII
# SK2
# 피테라리미티드에디션
# 나의이야기나의피테라
# sk2제공
# 백화수복
# 백화수복원컵
# 정종
# 프릴
# Pril
# 프릴시크릿오브베이킹소다
# 프릴주방세제
# 레진코믹스기프트카드
# #타라
# #홍차
# #홍차추천
# #프리미엄홍차
# #홈카페
# #티마스터
# #차한잔의여유
# #티타임
# #홍차스타그램
# #티스타그램
# #차스타그램
# #협찬이지만솔직후기
# 팬틴골든미라클
# 극손상헤어케어
# 헤어손상순삭
# 팬틴골든미라클팝업스토어
# 팬틴팝업스토어
# 컬트필름클럽
# 올드보이하우스
# dddd
# 이지덤뷰티
# 티안나게빨리낫자
# 이지덤
# 포니패치
# ##sponsoredbyPG
# #케어스타터
# #욕실토너
# #더마코스메틱
# #닦아쓰는토너
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-ebc9d0915fe3> in <module>()
#       3     try :
#       4         params = {'p':word}
# ----> 5         request_data = requests.get(api, params=params).text
#       6         json_data = json.loads(request_data)
#       7 #         print(json_data)
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Users\mediance_ssh\Anaconda3\lib\http\client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# C:\Users\mediance_ssh\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\mediance_ssh\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\mediance_ssh\Anaconda3\lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# C:\Users\mediance_ssh\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1332             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1333         else:
# -> 1334             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1335         self._raise_ssl_error(self._ssl, result)
#    1336
#
# KeyboardInterrupt:

# %%
import requests
import json

# %%
params = {'p':'일상'}
r = requests.get('https://b8k9yk75eb.execute-api.ap-northeast-2.amazonaws.com/tag_api/tag-analysis/tag-similar-request-by-name', params=params)
print(json.loads(r.text))
# Out:
# {'statusCode': 200, 'body': '["데일리", "소통", "좋아요", "인친", "맞팔", "daily", "팔로우", "선팔", "일상스타그램", "인스타그램", "선팔하면맞팔", "좋반", "소통해요", "환영해요", "일상daily", "오오티디", "데일리스타그램", "좋아요반사", "생각스타그램", "팔로워"]'}
